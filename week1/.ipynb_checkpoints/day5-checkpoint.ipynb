# %% [markdown]
# # Una solución empresarial completa
#
# ## Ahora llevaremos nuestro proyecto del día 1 al siguiente nivel
#
# ### DESAFÍO EMPRESARIAL:
#
# Crear un producto que genere un folleto para una empresa que se utilizará para posibles clientes, inversores y posibles reclutas.
#
# Se nos proporcionará un nombre de empresa y su sitio web principal.
#
# Consulte el final de este cuaderno para ver ejemplos de aplicaciones empresariales del mundo real.
#
# Y recuerde: ¡siempre estoy disponible si tiene problemas o ideas! No dude en comunicarse conmigo.

# %%
# imports
# Si esto falla, verifica que esté ejecutándose desde un entorno "activado" con (llms) en el símbolo del sistema

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Inicialización y constantes and constants

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key[:8]=='sk-proj-':
    print("La clave de API parece buena")
else:
    print("¿Puede haber un problema con tu clave API? ¡Visita el cuaderno de resolución de problemas!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# La clave de API parece buena

# %%
# La clase para representar una Página Web

class Website:
    """
    Una clase de utilidad para representar un sitio web que hemos scrappeado, ahora con enlaces
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "Sin título"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Título de la Web:\n{self.title}\nContenido de la Web:\n{self.text}\n\n"

# %%
frog = Website("https://cursos.frogamesformacion.com")
print(frog.get_contents())
#frog.links
# Out:
# Título de la Web:
# Frogames
# Contenido de la Web:
# Ir al contenido principal
# Frogames
# Menú alternativo
# Menú
# Iniciar sesión
# Ganadora del premio 'Enseñanza online de datos y competencias digitales más innovadora de Europa, 2023'
# Pasión por
# aprender
# con los
# mejores
# En Frogames Formación te ayudamos a convertirte en todo un experto en: Programación de Videojuegos, Inteligencia Artificial, Machine Learning, Desarrollo de Apps, Data Science y mucho más.
# Aprende mientras te diviertes
# Cursos, Rutas y Suscripciones
# Certificados de finalización
# Qué encontrarás
# dentro
# de Frogames
# Cursos online y formación de calidad para toda la família
# Rutas temáticas
# Rutas organizadas para que aprendas paso a paso, subiendo cada escalón e incrementando tus conocimientos adquiridos
# Instructores Expertos
# Con un equipo de profesionales y expertos en la materia que te acompañará a lo largo de todo el aprendizaje en la plataforma
# Certificados blockchain
# Títulos verificados por blockchain para cada habilidad que aprendas, listos para compartir en tus redes sociales y mejorar tu CV
# Constantes actualizaciones
# Cada semana añadiremos nuevos o actualizaremos nuestros cursos. Extenderemos las rutas con actualizaciones periódicas.
# Los
# cursos
# top
# Nuevos Lanzamientos
# Los más vendidos
# Todos los Cursos
# Prompt Engineering: Crea Apps Android 100% con Gemini IA
# 5.0
# (6)
# 71
# Ingeniería de IA y MLOps en Producción: IA Generativa y Agéntica a Gran Escala con AWS, GCP y Azure
# 5.0
# (8)
# 154
# Análisis de forecasting con Power BI
# 5.0
# (10)
# 7
# Analítica avanzada con Power BI
# 5.0
# (10)
# 20
# Power BI: Mi primer proyecto Fitness Life
# 5.0
# (11)
# 13
# Informe Ejecutivo de IA Generativa 2025: LLMs para Líderes
# 5.0
# (12)
# 21
# Aprende Matemáticas desde Cero - Geometría Analítica
# 5.0
# (9)
# 490
# Curso Completo de Ingeniería de Agentes de IA (2025)
# 5.0
# (18)
# 175
# Domina Android desde cero con Kotlin, Compose y Gemini AI
# 5.0
# (16)
# 692
# Domina las Interfaces de Usuario en Unity 6: De Cero a Experto en UI/UX Interactiva
# 5.0
# (18)
# 61
# Fundamentos Avanzados de Matemáticas para Machine Learning
# 5.0
# (12)
# 93
# Inteligencia Artificial en Flutter con Firebase AI
# 5.0
# (14)
# 39
# Aprende Matemáticas desde Cero - Aritmética
# 5.0
# (35)
# 345
# Guía definitiva de ChatGPT: domina la productividad con ejemplos reales
# 5.0
# (22)
# 82
# 15 días de Power BI - El bootcamp completo de Power BI
# 5.0
# (30)
# 199
# Machine Learning de la A a la Z
# 5.0
# (39)
# 304
# Curso de desarrollo de videojuegos con Unity 2021
# 5.0
# (30)
# 339
# Trading algorítmico para principiantes: de cero a héroe
# 5.0
# (28)
# 102
# Curso Completo de Unreal Engine 5
# 5.0
# (26)
# 128
# Curso completo de Python de la A a la Z
# 5.0
# (57)
# 498
# Más de
# 500.000
# estudiantes de
# todos
# los niveles satisfechos
# Nuestros estudiantes han desarrollado sus habilidades gracias a nuestros cursos. Estas son algunas de sus historias.
# Me gusta aprender en Frogames porque sus cursos son especializados
# Realmente prácticos, muy avanzados en contenido lo que es un reto muy emocionante. Estoy aprendiendo las bases matemáticas de los videojuegos, lo que pocos enseñan o solamente lo hacen superficialmente, siempre que ingreso a la plataforma estoy con una sonrisa de oreja a oreja
# Edwyn Mendoza
# Me encanta ser parte de una comunidad donde se aprende, crece y también se disfruta.
# Siempre estaré eternamente agradecida de todas las herramientas que Frogrames me ha entregado tan generosamente como persona y profesional. Lo recomiendo sin duda alguna con los ojos cerrados.
# Javiera Constanza Vallejos Jara
# Desde el primer momento elegí la suscripción anual por todas las ventajas que ofrece.
# Sabía que sería una decisión acertada desde el primer momento. Ahora puedo acceder a todos los cursos que quiero y con nuevo contenido cada semana. ¡Me encanta Frogames Formación!
# Matias Ángel Bloisi
# ¡Me encanta aprender aquí!
# Es el lugar adecuado para aprender diferentes temáticas en un solo lugar. Con profesores que dominan el tema y te ayudan en todo momento. Estoy encantado de estar junto a esta comunidad de amigos.
# Eulogio Enamorado Pallares
# Estoy muy satisfecho y lo recomiendo 100%
# Destaco de la plataforma es que el curso que me encuentro realizando, explican no sólo el curso en sí, sino cómo preparar los entornos de desarrollo que muchas veces se obvian en otros lados. Además el curso se lleva a cabo con un caso real en el cloud y también existen clases bono que permite realizar los casos como Senior, y que sólo se lograría con algunos años de experiencia.
# Alexis G. Álvarez
# Mi ilusión diaria es mi curso de Frogames
# A mis 45 años me decidí a estudiar programación, inicié un curso de FP, pero donde disfruto aprendiendo es en Frogames, la calidad de su equipo humano es la mejor que he visto hasta ahora en cursos online.
# Toni Peña Palencia
# Motivación y cambio positivo en la vida.
# Hubo en mi vida, un momento que necesitaba dar un giro, salir de la rutina, empecé a buscar nuevos desafíos y me encontré con Frogames. Aquí pude encontrar profesores con alto dominio en los temas actuales de matemáticas, programación e Inteligencia Artificial. Estoy feliz y fue una buena decisión.
# Christian Cadena R.
# Oportunidad de formación X2
# Me permite estudiar desarrollo de juegos y al mismo tiempo estudiar informática en la universidad, soy de Venezuela y jamás pensé en tener la oportunidad de aprender tantas cosas que amo a tan bajo precio y de forma tan completa en cualquier momento.
# Sebastián Terán
# En
# Frogames
# hemos creado una plataforma para gente como
# tú
# ...
# Licenciado en matemáticas y máster en educación. Juan Gabriel Gomila dedicó sus primeros años de trabajo en una empresa de videojuegos de Mallorca.
# Después de tres años, empezó a grabar cursos online en su casa para cumplir una misión: enseñar al resto del mundo lo que él había aprendido para dar opciones a todo el mundo que quisiera tomar sus cursos.
# Años después y con todo lo aprendido en varias plataformas como Udemy o Platzi, fundó Frogames junto a María Santos, donde el equipo docente de más de 20 instructores online ha enseñado a más de 500.000 estudiantes en todo el mundo en habla hispana.
# Empieza a aprender con nosotros hoy mismo
# Para que puedas conocer nuestra plataforma y todo lo que puedes aprender en ella, te hacemos entrega de este curso totalmente gratuito para que te inicies desde cero en el mundo del trading algorítmico con Python.
# ¡Así podrás conocer nuestras competiciones, certificados blockchain, logros, comunidad de estudiantes y mucho más!
# ¡Esperamos que lo disfrutes!
# ¡Sí! ¡Quiero mi curso gratis!
# Frogames Routes Grid
# Encuentra tu Camino
# 17 Rutas de Aprendizaje diseñadas para llevarte de cero a experto en las tecnologías
#             más demandadas.
# Análisis de Datos
# Android
# Matemáticas desde Cero
# Bases de Datos
# Blockchain
# Business Intelligence
# Desarrollo de Videojuegos
# Desarrollo Multiplataforma
# Desarrollo Web
# Emprendimiento
# Inteligencia Artificial
# iOS
# Lenguajes de Programación
# Matemáticas Avanzadas
# Música y Composición
# Ofimática y Productividad
# Trading Algorítmico
# Convalidación Frogames Formación
# Convalidación de cursos
# ¿Ya tienes un curso del catálogo de Frogames Formación en Udemy?
# Puedes convalidarlo con nosotros
# y seguir avanzando dentro de nuestra plataforma.
#                     Si ya has adquirido uno de nuestros cursos en Udemy, revisa el proceso de convalidación y solicita
#                     el acceso correspondiente desde aquí.
# Ver convalidación
# FORMACIÓN PARA EMPRESAS
# Frogames para
# Empresas
# marca una ventaja
# competitiva
# .
# Conoce a Alberto Valls, que ha aprendido a gestionar su planta en Valencia gracias a los cursos de Power BI
# Empresas formadas
# Frogames para Empresas
# Trustpilot
# Premios y Distinciones
# Frogames Formación y Juan Gabriel Gomila han ganado diversos
# premios y distinciones
# como plataforma educativa destacada a nivel mundial.
# Y SI QUIERES TRABAJAR CON NOSOTROS
# Puedes optar a convertirte afiliado y ser remunerado por cada venta que consigas
# Si tienes una audiencia o gestionas un grupo de personas interesadas en la formación, ¡Frogames tiene un sistema de afiliados que te recompensa por tu trabajo!
# +
# Frogames Cookie Banner
# 🍪
# Usamos cookies para que aprendas a programar, no para espiarte.
# Puedes leer nuestra
# política de privacidad
# .
# Rechazar
# Aceptar Todo
# Aviso Legal
# Política de Privacidad
# Términos de Uso
# Política de Cookies
# Política de Redes Sociales
# FAQs
# Frogames Facebook
#                     (Abrir en una nueva ventana)
# Frogames Twitter
#                     (Abrir en una nueva ventana)
# Frogames Youtube
#                     (Abrir en una nueva ventana)
# © Copyright Frogames 2026

# %%
frog.links
# Out:
# ['#main-content',
#  '/',
#  '/',
#  '/users/sign_in',
#  'https://cursos.frogamesformacion.com/pages/rutas',
#  'https://cursos.frogamesformacion.com/pages/instructores',
#  'https://cursos.frogamesformacion.com/pages/certificaciones',
#  'https://cursos.frogamesformacion.com/collections',
#  '/courses/prompt-engineering-android',
#  '/courses/prompt-engineering-android',
#  '/courses/ia-produccion',
#  '/courses/ia-produccion',
#  '/courses/power-bi-forecasting',
#  '/courses/power-bi-forecasting',
#  '/courses/analitica-avanzada-pbi',
#  '/courses/analitica-avanzada-pbi',
#  '/courses/power-bi-proyecto-fitness',
#  '/courses/power-bi-proyecto-fitness',
#  '/courses/ia-ejecutivos',
#  '/courses/ia-ejecutivos',
#  '/courses/geometria-analitica-desde-cero',
#  '/courses/geometria-analitica-desde-cero',
#  '/courses/agentes-ia',
#  '/courses/agentes-ia',
#  '/courses/domina-android-desde-cero-kotlin-compose',
#  '/courses/domina-android-desde-cero-kotlin-compose',
#  '/courses/unity-ui',
#  '/courses/unity-ui',
#  '/courses/matematicas-ml-3',
#  '/courses/matematicas-ml-3',
#  '/courses/flutter-firebase-ai',
#  '/courses/flutter-firebase-ai',
#  '/courses/aritmetica-desde-cero',
#  '/courses/aritmetica-desde-cero',
#  '/courses/chatgpt',
#  '/courses/chatgpt',
#  '/courses/15-dias-power-bi',
#  '/courses/15-dias-power-bi',
#  '/courses/machine-learning-az',
#  '/courses/machine-learning-az',
#  '/courses/unity-2021',
#  '/courses/unity-2021',
#  '/courses/trading-algoritmico-2',
#  '/courses/trading-algoritmico-2',
#  '/courses/unreal-5',
#  '/courses/unreal-5',
#  '/courses/python-az',
#  '/courses/python-az',
#  '/courses/trading-algoritmico-1',
#  '/bundles/ruta-analisis-datos',
#  '/bundles/ruta-android',
#  '/bundles/aprende-matematicas-desde-cero',
#  '/bundles/ruta-bases-datos',
#  '/bundles/ruta-blockchain',
#  '/bundles/ruta-business-intelligence',
#  '/bundles/ruta-videojuegos',
#  '/bundles/ruta-multiplataforma',
#  '/bundles/ruta-web',
#  '/bundles/ruta-emprendimiento',
#  '/bundles/ruta-inteligencia-artificial',
#  '/bundles/ruta-ios',
#  '/bundles/ruta-programacion',
#  '/bundles/ruta-matematicas',
#  '/bundles/ruta-musica',
#  '/bundles/ruta-ofimatica',
#  '/bundles/ruta-trading',
#  'https://cursos.frogamesformacion.com/courses/convalidacion-de-cursos-de-udemy',
#  '/pages/nuestros-clientes',
#  '/pages/frogames-para-empresas',
#  'https://es.trustpilot.com/review/cursos.frogamesformacion.com',
#  'https://www.emagister.com/opiniones-frogames-formacion-opincen-1171758.htm',
#  'https://cursos.frogamesformacion.com/pages/premios',
#  'https://www.corporatevision-news.com/issues/education-and-training-awards-2023/8/',
#  'https://cursos.frogamesformacion.com',
#  'https://thesiliconreview.com/magazine/profile/solidifying-position-global-online-education-platform-juan-gabriel-frogames-formacin',
#  'https://docenzia.com/frogames-formacion-informacion-opiniones-cursos-precios',
#  'https://www.ciobulletin.com/magazine/frogames-formacion-quality-spanish-language-courses',
#  'https://cursos.frogamesformacion.com/pages/afiliados',
#  '/pages/privacy',
#  '/pages/aviso-legal',
#  'https://cursos.frogamesformacion.com/pages/privacy',
#  'https://cursos.frogamesformacion.com/pages/terms',
#  '/pages/politica-de-cookies',
#  '/pages/politica-de-redes-sociales',
#  '/pages/faqs',
#  'https://www.facebook.com/froggames/',
#  'https://twitter.com/frogames_sl',
#  'https://www.youtube.com/channel/UCMUxXNYrVCv6-bQakhomvBg',
#  'https://wa.me/606784555']

# %% [markdown]
# ## Primer paso: hacer que GPT-4o-mini determine qué enlaces son relevantes
#
# ### Usar una llamada a gpt-4o-mini para leer los enlaces en una página web y responder en JSON estructurado.
# Debería decidir qué enlaces son relevantes y reemplazar los enlaces relativos como "/about" con "https://company.com/about".
# Usaremos "one shot prompting" en las que proporcionamos un ejemplo de cómo debería responder en la solicitud.
#
# Este es un excelente caso de uso para un LLM, porque requiere una comprensión matizada. Imagínate intentar programar esto sin LLMs analizando la página web: ¡sería muy difícil!
#
# Nota al margen: existe una técnica más avanzada llamada "Salidas estructuradas" en la que requerimos que el modelo responda de acuerdo con una especificación. Cubrimos esta técnica en la Semana 8 durante nuestro proyecto autónomo de inteligencia artificial Agentic.

# %%
link_system_prompt = "Se te proporciona una lista de enlaces que se encuentran en una página web. \
Puedes decidir cuáles de los enlaces serían los más relevantes para incluir en un folleto sobre la empresa, \
como enlaces a una página Acerca de, una página de la empresa, las carreras/empleos disponibles o páginas de Cursos/Packs.\n"
link_system_prompt += "Debes responder en JSON como en este ejemplo:"
link_system_prompt += """
{
    "links": [
        {"type": "Pagina Sobre nosotros", "url": "https://url.completa/aqui/va/sobre/nosotros"},
        {"type": "Pagina de Cursos": "url": "https://otra.url.completa/courses"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# Se te proporciona una lista de enlaces que se encuentran en una página web. Puedes decidir cuáles de los enlaces serían los más relevantes para incluir en un folleto sobre la empresa, como enlaces a una página Acerca de, una página de la empresa, las carreras/empleos disponibles o páginas de Cursos/Packs.
# Debes responder en JSON como en este ejemplo:
# {
#     "links": [
#         {"type": "Pagina Sobre nosotros", "url": "https://url.completa/aqui/va/sobre/nosotros"},
#         {"type": "Pagina de Cursos": "url": "https://otra.url.completa/courses"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Aquí hay una lista de enlaces de la página web {website.url} - "
    user_prompt += "Por favor, decide cuáles de estos son enlaces web relevantes para un folleto sobre la empresa. Responde con la URL https completa en formato JSON. \
No incluyas Términos y Condiciones, Privacidad ni enlaces de correo electrónico.\n"
    user_prompt += "Links (puede que algunos sean links relativos):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(frog))
# Out:
# Aquí hay una lista de enlaces de la página web https://cursos.frogamesformacion.com - Por favor, decide cuáles de estos son enlaces web relevantes para un folleto sobre la empresa. Responde con la URL https completa en formato JSON. No incluyas Términos y Condiciones, Privacidad ni enlaces de correo electrónico.
# Links (puede que algunos sean links relativos):
# #main-content
# /
# /
# /users/sign_in
# https://cursos.frogamesformacion.com/pages/rutas
# https://cursos.frogamesformacion.com/pages/instructores
# https://cursos.frogamesformacion.com/pages/certificaciones
# https://cursos.frogamesformacion.com/collections
# /courses/prompt-engineering-android
# /courses/prompt-engineering-android
# /courses/ia-produccion
# /courses/ia-produccion
# /courses/power-bi-forecasting
# /courses/power-bi-forecasting
# /courses/analitica-avanzada-pbi
# /courses/analitica-avanzada-pbi
# /courses/power-bi-proyecto-fitness
# /courses/power-bi-proyecto-fitness
# /courses/ia-ejecutivos
# /courses/ia-ejecutivos
# /courses/geometria-analitica-desde-cero
# /courses/geometria-analitica-desde-cero
# /courses/agentes-ia
# /courses/agentes-ia
# /courses/domina-android-desde-cero-kotlin-compose
# /courses/domina-android-desde-cero-kotlin-compose
# /courses/unity-ui
# /courses/unity-ui
# /courses/matematicas-ml-3
# /courses/matematicas-ml-3
# /courses/flutter-firebase-ai
# /courses/flutter-firebase-ai
# /courses/aritmetica-desde-cero
# /courses/aritmetica-desde-cero
# /courses/chatgpt
# /courses/chatgpt
# /courses/15-dias-power-bi
# /courses/15-dias-power-bi
# /courses/machine-learning-az
# /courses/machine-learning-az
# /courses/unity-2021
# /courses/unity-2021
# /courses/trading-algoritmico-2
# /courses/trading-algoritmico-2
# /courses/unreal-5
# /courses/unreal-5
# /courses/python-az
# /courses/python-az
# /courses/trading-algoritmico-1
# /bundles/ruta-analisis-datos
# /bundles/ruta-android
# /bundles/aprende-matematicas-desde-cero
# /bundles/ruta-bases-datos
# /bundles/ruta-blockchain
# /bundles/ruta-business-intelligence
# /bundles/ruta-videojuegos
# /bundles/ruta-multiplataforma
# /bundles/ruta-web
# /bundles/ruta-emprendimiento
# /bundles/ruta-inteligencia-artificial
# /bundles/ruta-ios
# /bundles/ruta-programacion
# /bundles/ruta-matematicas
# /bundles/ruta-musica
# /bundles/ruta-ofimatica
# /bundles/ruta-trading
# https://cursos.frogamesformacion.com/courses/convalidacion-de-cursos-de-udemy
# /pages/nuestros-clientes
# /pages/frogames-para-empresas
# https://es.trustpilot.com/review/cursos.frogamesformacion.com
# https://www.emagister.com/opiniones-frogames-formacion-opincen-1171758.htm
# https://cursos.frogamesformacion.com/pages/premios
# https://www.corporatevision-news.com/issues/education-and-training-awards-2023/8/
# https://cursos.frogamesformacion.com
# https://thesiliconreview.com/magazine/profile/solidifying-position-global-online-education-platform-juan-gabriel-frogames-formacin
# https://docenzia.com/frogames-formacion-informacion-opiniones-cursos-precios
# https://www.ciobulletin.com/magazine/frogames-formacion-quality-spanish-language-courses
# https://cursos.frogamesformacion.com/pages/afiliados
# /pages/privacy
# /pages/aviso-legal
# https://cursos.frogamesformacion.com/pages/privacy
# https://cursos.frogamesformacion.com/pages/terms
# /pages/politica-de-cookies
# /pages/politica-de-redes-sociales
# /pages/faqs
# https://www.facebook.com/froggames/
# https://twitter.com/frogames_sl
# https://www.youtube.com/channel/UCMUxXNYrVCv6-bQakhomvBg
# https://wa.me/606784555

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %% [markdown]
# anthropic = Website("https://anthropic.com")
# anthropic.links

# %% [markdown]
# anthropic = Website("https://www.urjc.es/")
# anthropic.links

# %% [markdown]
# anthropic = Website("https://servicios.urjc.es/practicas/ofertas/")
# anthropic.links

# %% [markdown]
# get_links("https://servicios.urjc.es/practicas/ofertas/")

# %%
get_links("https://cursos.frogamesformacion.com")
# Out:
# {'links': [{'type': 'Página Acerca de',
#    'url': 'https://cursos.frogamesformacion.com/pages/nuestros-clientes'},
#   {'type': 'Página de Instructores',
#    'url': 'https://cursos.frogamesformacion.com/pages/instructores'},
#   {'type': 'Página de Certificaciones',
#    'url': 'https://cursos.frogamesformacion.com/pages/certificaciones'},
#   {'type': 'Página de Cursos',
#    'url': 'https://cursos.frogamesformacion.com/collections'},
#   {'type': 'Página de Premios',
#    'url': 'https://cursos.frogamesformacion.com/pages/premios'},
#   {'type': 'Página para Empresas',
#    'url': 'https://cursos.frogamesformacion.com/pages/frogames-para-empresas'},
#   {'type': 'Página de Afiliados',
#    'url': 'https://cursos.frogamesformacion.com/pages/afiliados'},
#   {'type': 'Página Principal', 'url': 'https://cursos.frogamesformacion.com'}]}

# %% [markdown]
# ## Segundo paso: ¡crea el folleto!
#
# Reúne todos los detalles en otro mensaje para GPT4-o

# %% [markdown]
# def get_all_details(url):
#     result = "Landing page:\n"
#     result += Website(url).get_contents()
#     links = get_links(url)
#     print("Links encontrados:", links)
#     for link in links["links"]:
#         result += f"\n\n{link['type']}\n"
#         result += Website(link["url"]).get_contents()
#     return result

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Links encontrados:", links)
    for link in links["links"]:
         try:
            result += f"\n\n{link['type']}\n"
            result += Website(link["url"]).get_contents()
         except Exception as e:
            print(f"Error al acceder a {link['url']}: {e}")
            continue
    return result

# %%
print(get_all_details("https://cursos.frogamesformacion.com"))
# Out:
# Links encontrados: {'links': [{'type': 'Pagina de inicio', 'url': 'https://cursos.frogamesformacion.com'}, {'type': 'Pagina de Rutas', 'url': 'https://cursos.frogamesformacion.com/pages/rutas'}, {'type': 'Pagina de Instructores', 'url': 'https://cursos.frogamesformacion.com/pages/instructores'}, {'type': 'Pagina de Certificaciones', 'url': 'https://cursos.frogamesformacion.com/pages/certificaciones'}, {'type': 'Pagina de Nuestros Clientes', 'url': 'https://cursos.frogamesformacion.com/pages/nuestros-clientes'}, {'type': 'Pagina para Empresas', 'url': 'https://cursos.frogamesformacion.com/pages/frogames-para-empresas'}, {'type': 'Pagina de Premios', 'url': 'https://cursos.frogamesformacion.com/pages/premios'}, {'type': 'Pagina de Afiliados', 'url': 'https://cursos.frogamesformacion.com/pages/afiliados'}, {'type': 'Convalidación de Cursos', 'url': 'https://cursos.frogamesformacion.com/courses/convalidacion-de-cursos-de-udemy'}, {'type': 'Cursos', 'url': 'https://cursos.frogamesformacion.com/collections'}]}
# Landing page:
# Título de la Web:
# Frogames
# Contenido de la Web:
# Ir al contenido principal
# Frogames
# Menú alternativo
# Menú
# Iniciar sesión
# Ganadora del premio 'Enseñanza online de datos y competencias digitales más innovadora de Europa, 2023'
# Pasión por
# aprender
# con los
# mejores
# En Frogames Formación te ayudamos a convertirte en todo un experto en: Programación de Videojuegos, Inteligencia Artificial, Machine Learning, Desarrollo de Apps, Data Science y mucho más.
# Aprende mientras te diviertes
# Cursos, Rutas y Suscripciones
# Certificados de finalización
# Qué encontrarás
# dentro
# de Frogames
# Cursos online y formación de calidad para toda la família
# Rutas temáticas
# Rutas organizadas para que aprendas paso a paso, subiendo cada escalón e incrementando tus conocimientos adquiridos
# Instructores Expertos
# Con un equipo de profesionales y expertos en la materia que te acompañará a lo largo de todo el aprendizaje en la plataforma
# Certificados blockchain
# Títulos verificados por blockchain para cada habilidad que aprendas, listos para compartir en tus redes sociales y mejorar tu CV
# Constantes actualizaciones
# Cada semana añadiremos nuevos o actualizaremos nuestros cursos. Extenderemos las rutas con actualizaciones periódicas.
# Los
# cursos
# top
# Nuevos Lanzamientos
# Los más vendidos
# Todos los Cursos
# Prompt Engineering: Crea Apps Android 100% con Gemini IA
# 5.0
# (6)
# 71
# Ingeniería de IA y MLOps en Producción: IA Generativa y Agéntica a Gran Escala con AWS, GCP y Azure
# 5.0
# (8)
# 154
# Análisis de forecasting con Power BI
# 5.0
# (10)
# 7
# Analítica avanzada con Power BI
# 5.0
# (10)
# 20
# Power BI: Mi primer proyecto Fitness Life
# 5.0
# (11)
# 13
# Informe Ejecutivo de IA Generativa 2025: LLMs para Líderes
# 5.0
# (12)
# 21
# Aprende Matemáticas desde Cero - Geometría Analítica
# 5.0
# (9)
# 490
# Curso Completo de Ingeniería de Agentes de IA (2025)
# 5.0
# (18)
# 175
# Domina Android desde cero con Kotlin, Compose y Gemini AI
# 5.0
# (16)
# 692
# Domina las Interfaces de Usuario en Unity 6: De Cero a Experto en UI/UX Interactiva
# 5.0
# (18)
# 61
# Fundamentos Avanzados de Matemáticas para Machine Learning
# 5.0
# (12)
# 93
# Inteligencia Artificial en Flutter con Firebase AI
# 5.0
# (14)
# 39
# Aprende Matemáticas desde Cero - Aritmética
# 5.0
# (35)
# 345
# Guía definitiva de ChatGPT: domina la productividad con ejemplos reales
# 5.0
# (22)
# 82
# 15 días de Power BI - El bootcamp completo de Power BI
# 5.0
# (30)
# 199
# Machine Learning de la A a la Z
# 5.0
# (39)
# 304
# Curso de desarrollo de videojuegos con Unity 2021
# 5.0
# (30)
# 339
# Trading algorítmico para principiantes: de cero a héroe
# 5.0
# (28)
# 102
# Curso Completo de Unreal Engine 5
# 5.0
# (26)
# 128
# Curso completo de Python de la A a la Z
# 5.0
# (57)
# 498
# Más de
# 500.000
# estudiantes de
# todos
# los niveles satisfechos
# Nuestros estudiantes han desarrollado sus habilidades gracias a nuestros cursos. Estas son algunas de sus historias.
# Me gusta aprender en Frogames porque sus cursos son especializados
# Realmente prácticos, muy avanzados en contenido lo que es un reto muy emocionante. Estoy aprendiendo las bases matemáticas de los videojuegos, lo que pocos enseñan o solamente lo hacen superficialmente, siempre que ingreso a la plataforma estoy con una sonrisa de oreja a oreja
# Edwyn Mendoza
# Me encanta ser parte de una comunidad donde se aprende, crece y también se disfruta.
# Siempre estaré eternamente agradecida de todas las herramientas que Frogrames me ha entregado tan generosamente como persona y profesional. Lo recomiendo sin duda alguna con los ojos cerrados.
# Javiera Constanza Vallejos Jara
# Desde el primer momento elegí la suscripción anual por todas las ventajas que ofrece.
# Sabía que sería una decisión acertada desde el primer momento. Ahora puedo acceder a todos los cursos que quiero y con nuevo contenido cada semana. ¡Me encanta Frogames Formación!
# Matias Ángel Bloisi
# ¡Me encanta aprender aquí!
# Es el lugar adecuado para aprender diferentes temáticas en un solo lugar. Con profesores que dominan el tema y te ayudan en todo momento. Estoy encantado de estar junto a esta comunidad de amigos.
# Eulogio Enamorado Pallares
# Estoy muy satisfecho y lo recomiendo 100%
# Destaco de la plataforma es que el curso que me encuentro realizando, explican no sólo el curso en sí, sino cómo preparar los entornos de desarrollo que muchas veces se obvian en otros lados. Además el curso se lleva a cabo con un caso real en el cloud y también existen clases bono que permite realizar los casos como Senior, y que sólo se lograría con algunos años de experiencia.
# Alexis G. Álvarez
# Mi ilusión diaria es mi curso de Frogames
# A mis 45 años me decidí a estudiar programación, inicié un curso de FP, pero donde disfruto aprendiendo es en Frogames, la calidad de su equipo humano es la mejor que he visto hasta ahora en cursos online.
# Toni Peña Palencia
# Motivación y cambio positivo en la vida.
# Hubo en mi vida, un momento que necesitaba dar un giro, salir de la rutina, empecé a buscar nuevos desafíos y me encontré con Frogames. Aquí pude encontrar profesores con alto dominio en los temas actuales de matemáticas, programación e Inteligencia Artificial. Estoy feliz y fue una buena decisión.
# Christian Cadena R.
# Oportunidad de formación X2
# Me permite estudiar desarrollo de juegos y al mismo tiempo estudiar informática en la universidad, soy de Venezuela y jamás pensé en tener la oportunidad de aprender tantas cosas que amo a tan bajo precio y de forma tan completa en cualquier momento.
# Sebastián Terán
# En
# Frogames
# hemos creado una plataforma para gente como
# tú
# ...
# Licenciado en matemáticas y máster en educación. Juan Gabriel Gomila dedicó sus primeros años de trabajo en una empresa de videojuegos de Mallorca.
# Después de tres años, empezó a grabar cursos online en su casa para cumplir una misión: enseñar al resto del mundo lo que él había aprendido para dar opciones a todo el mundo que quisiera tomar sus cursos.
# Años después y con todo lo aprendido en varias plataformas como Udemy o Platzi, fundó Frogames junto a María Santos, donde el equipo docente de más de 20 instructores online ha enseñado a más de 500.000 estudiantes en todo el mundo en habla hispana.
# Empieza a aprender con nosotros hoy mismo
# Para que puedas conocer nuestra plataforma y todo lo que puedes aprender en ella, te hacemos entrega de este curso totalmente gratuito para que te inicies desde cero en el mundo del trading algorítmico con Python.
# ¡Así podrás conocer nuestras competiciones, certificados blockchain, logros, comunidad de estudiantes y mucho más!
# ¡Esperamos que lo disfrutes!
# ¡Sí! ¡Quiero mi curso gratis!
# Frogames Routes Grid
# Encuentra tu Camino
# 17 Rutas de Aprendizaje diseñadas para llevarte de cero a experto en las tecnologías
#             más demandadas.
# Análisis de Datos
# Android
# Matemáticas desde Cero
# Bases de Datos
# Blockchain
# Business Intelligence
# Desarrollo de Videojuegos
# Desarrollo Multiplataforma
# Desarrollo Web
# Emprendimiento
# Inteligencia Artificial
# iOS
# Lenguajes de Programación
# Matemáticas Avanzadas
# Música y Composición
# Ofimática y Productividad
# Trading Algorítmico
# Convalidación Frogames Formación
# Convalidación de cursos
# ¿Ya tienes un curso del catálogo de Frogames Formación en Udemy?
# Puedes convalidarlo con nosotros
# y seguir avanzando dentro de nuestra plataforma.
#                     Si ya has adquirido uno de nuestros cursos en Udemy, revisa el proceso de convalidación y solicita
#                     el acceso correspondiente desde aquí.
# Ver convalidación
# FORMACIÓN PARA EMPRESAS
# Frogames para
# Empresas
# marca una ventaja
# competitiva
# .
# Conoce a Alberto Valls, que ha aprendido a gestionar su planta en Valencia gracias a los cursos de Power BI
# Empresas formadas
# Frogames para Empresas
# Trustpilot
# Premios y Distinciones
# Frogames Formación y Juan Gabriel Gomila han ganado diversos
# premios y distinciones
# como plataforma educativa destacada a nivel mundial.
# Y SI QUIERES TRABAJAR CON NOSOTROS
# Puedes optar a convertirte afiliado y ser remunerado por cada venta que consigas
# Si tienes una audiencia o gestionas un grupo de personas interesadas en la formación, ¡Frogames tiene un sistema de afiliados que te recompensa por tu trabajo!
# +
# Frogames Cookie Banner
# 🍪
# Usamos cookies para que aprendas a programar, no para espiarte.
# Puedes leer nuestra
# política de privacidad
# .
# Rechazar
# Aceptar Todo
# Aviso Legal
# Política de Privacidad
# Términos de Uso
# Política de Cookies
# Política de Redes Sociales
# FAQs
# Frogames Facebook
#                     (Abrir en una nueva ventana)
# Frogames Twitter
#                     (Abrir en una nueva ventana)
# Frogames Youtube
#                     (Abrir en una nueva ventana)
# © Copyright Frogames 2026
#
#
#
# Pagina de inicio
# Título de la Web:
# Frogames
# Contenido de la Web:
# Ir al contenido principal
# Frogames
# Menú alternativo
# Menú
# Iniciar sesión
# Ganadora del premio 'Enseñanza online de datos y competencias digitales más innovadora de Europa, 2023'
# Pasión por
# aprender
# con los
# mejores
# En Frogames Formación te ayudamos a convertirte en todo un experto en: Programación de Videojuegos, Inteligencia Artificial, Machine Learning, Desarrollo de Apps, Data Science y mucho más.
# Aprende mientras te diviertes
# Cursos, Rutas y Suscripciones
# Certificados de finalización
# Qué encontrarás
# dentro
# de Frogames
# Cursos online y formación de calidad para toda la família
# Rutas temáticas
# Rutas organizadas para que aprendas paso a paso, subiendo cada escalón e incrementando tus conocimientos adquiridos
# Instructores Expertos
# Con un equipo de profesionales y expertos en la materia que te acompañará a lo largo de todo el aprendizaje en la plataforma
# Certificados blockchain
# Títulos verificados por blockchain para cada habilidad que aprendas, listos para compartir en tus redes sociales y mejorar tu CV
# Constantes actualizaciones
# Cada semana añadiremos nuevos o actualizaremos nuestros cursos. Extenderemos las rutas con actualizaciones periódicas.
# Los
# cursos
# top
# Nuevos Lanzamientos
# Los más vendidos
# Todos los Cursos
# Prompt Engineering: Crea Apps Android 100% con Gemini IA
# 5.0
# (6)
# 71
# Ingeniería de IA y MLOps en Producción: IA Generativa y Agéntica a Gran Escala con AWS, GCP y Azure
# 5.0
# (8)
# 154
# Análisis de forecasting con Power BI
# 5.0
# (10)
# 7
# Analítica avanzada con Power BI
# 5.0
# (10)
# 20
# Power BI: Mi primer proyecto Fitness Life
# 5.0
# (11)
# 13
# Informe Ejecutivo de IA Generativa 2025: LLMs para Líderes
# 5.0
# (12)
# 21
# Aprende Matemáticas desde Cero - Geometría Analítica
# 5.0
# (9)
# 490
# Curso Completo de Ingeniería de Agentes de IA (2025)
# 5.0
# (18)
# 175
# Domina Android desde cero con Kotlin, Compose y Gemini AI
# 5.0
# (16)
# 692
# Domina las Interfaces de Usuario en Unity 6: De Cero a Experto en UI/UX Interactiva
# 5.0
# (18)
# 61
# Fundamentos Avanzados de Matemáticas para Machine Learning
# 5.0
# (12)
# 93
# Inteligencia Artificial en Flutter con Firebase AI
# 5.0
# (14)
# 39
# Aprende Matemáticas desde Cero - Aritmética
# 5.0
# (35)
# 345
# Guía definitiva de ChatGPT: domina la productividad con ejemplos reales
# 5.0
# (22)
# 82
# 15 días de Power BI - El bootcamp completo de Power BI
# 5.0
# (30)
# 199
# Machine Learning de la A a la Z
# 5.0
# (39)
# 304
# Curso de desarrollo de videojuegos con Unity 2021
# 5.0
# (30)
# 339
# Trading algorítmico para principiantes: de cero a héroe
# 5.0
# (28)
# 102
# Curso Completo de Unreal Engine 5
# 5.0
# (26)
# 128
# Curso completo de Python de la A a la Z
# 5.0
# (57)
# 498
# Más de
# 500.000
# estudiantes de
# todos
# los niveles satisfechos
# Nuestros estudiantes han desarrollado sus habilidades gracias a nuestros cursos. Estas son algunas de sus historias.
# Me gusta aprender en Frogames porque sus cursos son especializados
# Realmente prácticos, muy avanzados en contenido lo que es un reto muy emocionante. Estoy aprendiendo las bases matemáticas de los videojuegos, lo que pocos enseñan o solamente lo hacen superficialmente, siempre que ingreso a la plataforma estoy con una sonrisa de oreja a oreja
# Edwyn Mendoza
# Me encanta ser parte de una comunidad donde se aprende, crece y también se disfruta.
# Siempre estaré eternamente agradecida de todas las herramientas que Frogrames me ha entregado tan generosamente como persona y profesional. Lo recomiendo sin duda alguna con los ojos cerrados.
# Javiera Constanza Vallejos Jara
# Desde el primer momento elegí la suscripción anual por todas las ventajas que ofrece.
# Sabía que sería una decisión acertada desde el primer momento. Ahora puedo acceder a todos los cursos que quiero y con nuevo contenido cada semana. ¡Me encanta Frogames Formación!
# Matias Ángel Bloisi
# ¡Me encanta aprender aquí!
# Es el lugar adecuado para aprender diferentes temáticas en un solo lugar. Con profesores que dominan el tema y te ayudan en todo momento. Estoy encantado de estar junto a esta comunidad de amigos.
# Eulogio Enamorado Pallares
# Estoy muy satisfecho y lo recomiendo 100%
# Destaco de la plataforma es que el curso que me encuentro realizando, explican no sólo el curso en sí, sino cómo preparar los entornos de desarrollo que muchas veces se obvian en otros lados. Además el curso se lleva a cabo con un caso real en el cloud y también existen clases bono que permite realizar los casos como Senior, y que sólo se lograría con algunos años de experiencia.
# Alexis G. Álvarez
# Mi ilusión diaria es mi curso de Frogames
# A mis 45 años me decidí a estudiar programación, inicié un curso de FP, pero donde disfruto aprendiendo es en Frogames, la calidad de su equipo humano es la mejor que he visto hasta ahora en cursos online.
# Toni Peña Palencia
# Motivación y cambio positivo en la vida.
# Hubo en mi vida, un momento que necesitaba dar un giro, salir de la rutina, empecé a buscar nuevos desafíos y me encontré con Frogames. Aquí pude encontrar profesores con alto dominio en los temas actuales de matemáticas, programación e Inteligencia Artificial. Estoy feliz y fue una buena decisión.
# Christian Cadena R.
# Oportunidad de formación X2
# Me permite estudiar desarrollo de juegos y al mismo tiempo estudiar informática en la universidad, soy de Venezuela y jamás pensé en tener la oportunidad de aprender tantas cosas que amo a tan bajo precio y de forma tan completa en cualquier momento.
# Sebastián Terán
# En
# Frogames
# hemos creado una plataforma para gente como
# tú
# ...
# Licenciado en matemáticas y máster en educación. Juan Gabriel Gomila dedicó sus primeros años de trabajo en una empresa de videojuegos de Mallorca.
# Después de tres años, empezó a grabar cursos online en su casa para cumplir una misión: enseñar al resto del mundo lo que él había aprendido para dar opciones a todo el mundo que quisiera tomar sus cursos.
# Años después y con todo lo aprendido en varias plataformas como Udemy o Platzi, fundó Frogames junto a María Santos, donde el equipo docente de más de 20 instructores online ha enseñado a más de 500.000 estudiantes en todo el mundo en habla hispana.
# Empieza a aprender con nosotros hoy mismo
# Para que puedas conocer nuestra plataforma y todo lo que puedes aprender en ella, te hacemos entrega de este curso totalmente gratuito para que te inicies desde cero en el mundo del trading algorítmico con Python.
# ¡Así podrás conocer nuestras competiciones, certificados blockchain, logros, comunidad de estudiantes y mucho más!
# ¡Esperamos que lo disfrutes!
# ¡Sí! ¡Quiero mi curso gratis!
# Frogames Routes Grid
# Encuentra tu Camino
# 17 Rutas de Aprendizaje diseñadas para llevarte de cero a experto en las tecnologías
#             más demandadas.
# Análisis de Datos
# Android
# Matemáticas desde Cero
# Bases de Datos
# Blockchain
# Business Intelligence
# Desarrollo de Videojuegos
# Desarrollo Multiplataforma
# Desarrollo Web
# Emprendimiento
# Inteligencia Artificial
# iOS
# Lenguajes de Programación
# Matemáticas Avanzadas
# Música y Composición
# Ofimática y Productividad
# Trading Algorítmico
# Convalidación Frogames Formación
# Convalidación de cursos
# ¿Ya tienes un curso del catálogo de Frogames Formación en Udemy?
# Puedes convalidarlo con nosotros
# y seguir avanzando dentro de nuestra plataforma.
#                     Si ya has adquirido uno de nuestros cursos en Udemy, revisa el proceso de convalidación y solicita
#                     el acceso correspondiente desde aquí.
# Ver convalidación
# FORMACIÓN PARA EMPRESAS
# Frogames para
# Empresas
# marca una ventaja
# competitiva
# .
# Conoce a Alberto Valls, que ha aprendido a gestionar su planta en Valencia gracias a los cursos de Power BI
# Empresas formadas
# Frogames para Empresas
# Trustpilot
# Premios y Distinciones
# Frogames Formación y Juan Gabriel Gomila han ganado diversos
# premios y distinciones
# como plataforma educativa destacada a nivel mundial.
# Y SI QUIERES TRABAJAR CON NOSOTROS
# Puedes optar a convertirte afiliado y ser remunerado por cada venta que consigas
# Si tienes una audiencia o gestionas un grupo de personas interesadas en la formación, ¡Frogames tiene un sistema de afiliados que te recompensa por tu trabajo!
# +
# Frogames Cookie Banner
# 🍪
# Usamos cookies para que aprendas a programar, no para espiarte.
# Puedes leer nuestra
# política de privacidad
# .
# Rechazar
# Aceptar Todo
# Aviso Legal
# Política de Privacidad
# Términos de Uso
# Política de Cookies
# Política de Redes Sociales
# FAQs
# Frogames Facebook
#                     (Abrir en una nueva ventana)
# Frogames Twitter
#                     (Abrir en una nueva ventana)
# Frogames Youtube
#                     (Abrir en una nueva ventana)
# © Copyright Frogames 2026
#
#
#
# Pagina de Rutas
# Título de la Web:
# Rutas
# Contenido de la Web:
# Ir al contenido principal
# Frogames
# Menú alternativo
# Menú
# Iniciar sesión
# Frogames Routes Grid
# Encuentra tu Camino en el Mapa Galáctico
# 17 Rutas de Aprendizaje diseñadas para llevarte de cero a experto en las tecnologías
#             más demandadas.
# Frogames Routes Graph
# La suscripción a todo Frogames
# Suscripción Rana de Oro
# Paquete
#
#             • 224 productos didácticos
# Invierte en tu formación y ahorra 3 meses de suscripción con la Rana de Oro para convertirte en un experto en IA, videojuegos, matemáticas, trading o blockchain ¡y alcanza límites únicos en tu carrera profesional con nuestra suscripción anual!
# €349
# / año
# Comprar ahora
# Suscripción Rana de Bronce
# • 224 productos didácticos
# €39
# / mes
# Suscripción Rana de Plata
# • 225 productos didácticos
# €199
# / 6 meses
# Rana Black
# • 240 productos didácticos
# €7.999
# Preguntas Frecuentes
# ¿Qué son las rutas de aprendizaje de Frogames?
# Las rutas de aprendizaje de Frogames son el camino directo para aprender temas como matemáticas, análisis de datos, desarrollo de videojuegos o programación de apps entre otros. En nuestras rutas, hemos juntado todos los cursos fundamentales y opcionales que necesitas para dominar las materias en un pack único que te permite obtener todos los cursos en un único pago (para siempre) o bien con suscripciones mensuales o anuales (para acceder solamente cuando lo necesites).
# ¿Cuando se añaden nuevos cursos hay que volver a pagarlos?
# Si obtienes la ruta de por vida, claro que no. Cuando obtienes una ruta vitalicia, te haces con los cursos existentes, con sus actualizaciones, nuevos lanzamientos de la ruta y cualquier extra que vaya a contener la misma. Eso significa que ahora puede que pagues por acceder a 12 cursos de la rama de IA, pero que en unos años, tengas acceso a 20 o más.
# ¿Las rutas cambian y se actualizan con el tiempo?
# Pues claro que sí. Si un tema cambia, puede que volvamos a grabar alguna sección de los cursos, o bien que lancemos un curso 100% actualizado. Incluso, todos sabemos que nuevas tecnologías nacen cada año, y por eso las rutas suelen tener nuevos cursos cada cierto tiempo.
# ¿Puedo obtener una o varias rutas con descuento?
# Pues sí. Las rutas a veces comparten cursos pero por lo menos 80% del contenido es único y exclusivo de cada ruta. Eso significa que puedes hacerte con una ruta, dos, tres o todas las que quieras. De hecho, si buscas el modelo de suscripción, la rana de bronce, plata u oro te sale más económica a largo plazo.
#
# Los accesos en formato suscripción mensual, de 6 meses o anual no cuentan con descuentos por su naturaleza de pago recurrente, y el precio ajustado que ya tienen al incluir tanto material. Además, si te suscribes, según nuestra política NUNCA te subiremos el precio mientras mantengas la suscripción activa. Así de simple
# Aviso Legal
# Política de Privacidad
# Términos de Uso
# Política de Cookies
# Política de Redes Sociales
# FAQs
# Frogames Facebook
#                     (Abrir en una nueva ventana)
# Frogames Twitter
#                     (Abrir en una nueva ventana)
# Frogames Youtube
#                     (Abrir en una nueva ventana)
# © Copyright Frogames 2026
#
#
#
# Pagina de Instructores
# Título de la Web:
# Instructores de Frogames Formación
# Contenido de la Web:
# Ir al contenido principal
# Frogames
# Menú alternativo
# Menú
# Iniciar sesión
# Los instructores de Frogames
# Conoce a todos los instructores y colaboradores de Frogames Formación
# Watch Intro Video
# Juan Gabriel Gomila
# CEO de Frogames e Instructor Best Seller
# Conoce a Juan Gabriel
# María Santos
# Matemática y creadora de cursos e historias de aprendizaje
# Conoce a María
# Ligency
# Equipo de profesionales que ha enseñado a millones de estudiantes
# Conoce a Ligency
# Mateu Mercer
# CMO en Frogames
# Conoce a Mateu
# Arnau Mir
# Matemático experto en cálculo numérico
# Conoce a Arnau
# Ricardo Alberich
# Matemático experto en estadística
# Conoce a Ricardo
# Pedro Daniel Alcalá
# Experto en análisis de negocios
# Conoce a Pedro
# Alain Nicolás
# Experto en Android
# Conoce al Alain
# Joan Pont
# Ingeniero Telemático y Matemático
# Conoce a Joan
# Mariano Sosa
# Desarrollador de Videojuegos
# Conoce al Mariano
# Carlos Bastida Zapien
# Business Coach
# Conoce a Carlos
# Ana Vassallo
# Ingeniera de Software y Artista 3D
# Conoce a Ana
# Benjamin Miró
# Artista de videojuegos
# Conoce a Benji
# Sergio Dominguez
# Almirante Mayor General Supremo de Unreal Engine en Frogames
# Conoce a Sergio
# John Morales
# Estudiante de Ingeniería de Tecnologías de la Información y Comunicación
# Conoce a John
# Rocío Chavez
# Doctora en Tecnologías de Información
# Conoce a Rocío
# Jose Antonio Corral
# Desarrollador Senior Full Stack
# Conoce a Jose Antonio Corral F
# Anto Aja Escudero
# Entusiasta de la toma de notas
# Conoce a Anto
# María José Hidalgo
# Especialista en Accesibilidad Web
# Conoce a María José
# Denis Panjuta
# CEO de TutorialsEU
# Conoce a Denis
# Oak Academy
# Algunos explican, nosotros enseñamos
# Conoce Oak Academy
# Aviso Legal
# Política de Privacidad
# Términos de Uso
# Política de Cookies
# Política de Redes Sociales
# FAQs
# Frogames Facebook
#                     (Abrir en una nueva ventana)
# Frogames Twitter
#                     (Abrir en una nueva ventana)
# Frogames Youtube
#                     (Abrir en una nueva ventana)
# © Copyright Frogames 2026
#
#
#
# Pagina de Certificaciones
# Título de la Web:
# CERTIFICACIONES
# Contenido de la Web:
# Ir al contenido principal
# Frogames
# Menú alternativo
# Menú
# Iniciar sesión
# CERTIFICACIONES
# En Frogames Formación una vez completado un curso con éxito obtendrás una certificación digital validado por Blockchain.
# Insignias y certificados para todos tus logros
# Completar un curso, una temática, un nivel o una ruta completa tiene su recompensa adicional para tu currículum sin ningún tipo de gasto adicional
# ¿Cómo compartir la certificación por redes sociales?
# ¿Qué es una Certificación Blockchain?
# Una Certificación Blockchain es una validación consensuada por los nodos (gracias a sus firmas digitales) de que la información aportada, una vez verificada, será asegurada en su inmutabilidad y su integridad.
# Al tratarse de un sistema descentralizado, Blockchain lo componen todos los nodos por los que la información navega. Eso es lo que lo hace un sistema capaz de aportar seguridad y veracidad a la información.
# ¿En qué orden conseguir los certificados?
# Puedes acceder a nuestro portal de certificados en https://certificates.frogamesformacion.com
# ¿Para qué sirve una Certificación Blockchain?
# Se trata de un asiento que certifica que una obra determinada con un contenido determinado existe por causa de un autor desde una fecha concreta. Su principal función es, por tanto, la de verificar, en caso de disputa, la autoría del producto.
# Gracias a esto podrás validar de forma segura tu certificación obtenida en Frogames Formación.
# MEJORA TU VISIBILIDAD EN LINKEDIN
# Mejora tu hoja de vida con sólo unos clicks
# Cada curso que completes o convalides desde Udemy te dará acceso a una insignia o un certificado blockchain que podrás añadir a tu LinkedIn
# Leer más
# Certificaciones a tu medida
# Cuatro niveles posibles de certificación
# Obtén certificaciones por cada curso, temática, nivel de dificultad o ruta que completes en Frogames Formación
# Ver todas las Certificaciones
# Avalados por la metodología de expertos
# Y con los estándares de la educación del siglo XXI
# Nuestras certificaciones vienen avaladas por la empresa certificadora
# Accredible
# , un grupo de más de 20 expertos de todo el mundo y utilizando el estándar de la
# Taxonomía de Bloom
# , para indicar el nivel de profundización en los conocimientos que adquieras en nuestros cursos
# ¿Y si ya había completado mi curso en otra plataforma?
# Te ofrecemos el plan de actualización al certificado blockchain pagando únicamente las tasas de expedición
# Sabemos que las certificaciones validadas por blockchain
# te van a ser de mucha utilidad
# . Por ello, si ya habías completado uno de nuestros cursos en otra plataforma (como por ejemplo Udemy), y dispones de la certificación final que lo demuestra, te ofrecemos el plan de convalidación de certificados:
# Adquiere el servicio
# Convalidación de Cursos de Udemy
# por cuantos cursos necesites convalidar (de 1 a 5 por tanda de convalidación).
# Te responderemos en un plazo de 24 a 48h indicándote si debes aportar alguna documentación adicional.
# Obtendrás acceso al curso que ya tenías en Udemy, actualizado y con soporte del instructor, además del certificado blockchain si ya lo habías completado anteriormente sin esfuerzo adicional.
# Convalida tu curso ahora
# Convalidación de Cursos de Udemy
# Curso
# Trae tu curso de Udemy a Frogames y llévate el soporte del instructor, la comunidad exclusiva de alumnos, los extras para alumnos de Frogames (cuaderno de notas, competiciones, tienda virtual) y el ansiado certificado blockchain de finalización.
# €50
# Comprar ahora
# ×
# Some text in the Modal..
# semanas
# h
# clases
# Ver ahora
# Aviso Legal
# Política de Privacidad
# Términos de Uso
# Política de Cookies
# Política de Redes Sociales
# FAQs
# Frogames Facebook
#                     (Abrir en una nueva ventana)
# Frogames Twitter
#                     (Abrir en una nueva ventana)
# Frogames Youtube
#                     (Abrir en una nueva ventana)
# © Copyright Frogames 2026
#
#
#
# Pagina de Nuestros Clientes
# Título de la Web:
# Empresas que han aprendido con Frogames
# Contenido de la Web:
# Ir al contenido principal
# Frogames
# Menú alternativo
# Menú
# Iniciar sesión
# Empresas formadas con Frogames
# Nuestro catálogo ayuda a decenas de empresas cada año
# Empresas formadas por Juan Gabriel Gomila
# Catálogo de empresas que han recibido formaciones online o presenciales de la mano de Juan Gabriel Gomila, CEO de Frogames Formación
# Y también colaboran con Frogames
# Conoce las entidades y plataformas que colaboran con el equipo de Frogames Formación aportando valor a nuestro catálogo de cursos online
# Aviso Legal
# Política de Privacidad
# Términos de Uso
# Política de Cookies
# Política de Redes Sociales
# FAQs
# Frogames Facebook
#                     (Abrir en una nueva ventana)
# Frogames Twitter
#                     (Abrir en una nueva ventana)
# Frogames Youtube
#                     (Abrir en una nueva ventana)
# © Copyright Frogames 2026
#
#
#
# Pagina para Empresas
# Título de la Web:
# El valor cuantificado del aprendizaje virtual con Frogames
# Contenido de la Web:
# Ir al contenido principal
# Frogames
# Menú alternativo
# Menú
# Iniciar sesión
# Frogames para Empresas
# Si tienes una empresas y necesitas formar al personal, tenemos un plan especial para ti
# Contactar con Frogames
# ¿En qué consiste Frogames para Empresas?
# Actualizado en Diciembre de 2022
# Frogames para Empresas es un proyecto que nace con el objetivo de apoyar empresas, negocios  y startups para impulsar impulsar el crecimiento de sus empleados, trabajadores, becarios y colaboradores, para motivarles a aprender y desarrollar nuevas habilidades técnicas y competencias a través de nuestro catálogo de cursos online y rutas temáticas.
# Nuestro objetivo es el de potenciar el talento humano que permitirá evolucionar los negocios, y para ello las empresas podrán beneficiarse de Frogames Formación y obtener una oportunidad de acceder a una plataforma de aprendizaje para mantenerse actualizados, certificados gracias a nuestras certificaciones blockchain, y a la última en tecnologías del desarrollo y habilidades complementarias.
# VENTAJAS DEL SERVICIO PARA LAS EMPRESAS
# Frogames para Empresas pone a disposición de las empresas, un catálogo de cursos que no para de crecer y actualizarse, y la posibilidad de proponer nuevos cursos a futuro basados en las necesidades de la propia empresa.  Al ser un servicio dirigido para varias personas, nuestros paquetes pueden aplicar descuentos especiales que no están disponibles de ningún otro modo.
# CONDICIONES DEL SERVICIO
# Frogames para Empresas cuenta con las siguientes condiciones para el uso del servicio:
# Los beneficios que ofrece Frogames para Empresas son aplicables para empresas que deseen formar de 5 a más trabajadores.
# El precio del pack puede variar, ya que está sujeto a una evaluación previa según las necesidades específicas de la empresa que solicita nuestros servicios. Llegando a un acuerdo mutuo entre la empresa y Frogames Formación para determinar la viabilidad del servicio que ofrecemos. De momento no ofrecemos el servicio de cursos o seminarios personalizados que requieran la presencia de nuestros instructores o co-instructores ni física ni virtual.
# Nuestros cursos no están disponibles para subirlos a otras plataformas. Es decir, su visualización, administración y actualización de contenido se realiza en la plataforma de Frogames Formación.
# El soporte técnico sobre nuestros productos o servicios, es aplicable de la misma manera que se aplica a todos los usuarios suscritos en nuestra plataforma.
# Así mismo, en el servicio de Frogames para Empresas, son aplicables nuestras
# Políticas de Privacidad
# , nuestros
# Términos de uso de la plataforma
# así como las políticas de privacidad y de cookies actuales. Estas condiciones pueden cambiar, y ser actualizadas con el tiempo, según cambien las necesidades de nuestros clientes, la legislación vigente así como cambios en las políticas y servicios de Frogames Formación.
# CONTÁCTANOS PARA SABER MÁS
# Estamos a tu disposición para informarte
# Si deseas más información sobre Frogames para Empresas, mándanos un correo electrónico con la siguiente información para poder analizar tu situación particular sin ningún tipo de compromiso.
# Frogames para Empresas - "Nombre de tu Empresa"
# , y compártenos tus necesidades, indicando la siguiente información:
# ✔️ Cantidad de empleados para la formación
# ✔️  Periodo de suscripción
# ✔️  Consideraciones especiales a considerar
# Con mucho gusto nuestro equipo evaluará tu solicitud y creará un paquete con la oferta que se adapte mejor a tus necesidades.
# Solicitar propuesta sin compromiso
# El valor cuantificado de la formación online con Frogames
# Las personas que participaron en una encuesta elaborada por Frogames indica que la plataforma online ofrece a su personal una amplia gama de posibilidades de formación que les proporcionan tanto la capacidad específica necesaria para sus funciones como la competencia de gestión. esto permite que aprendan y mejoren en metodologías y uso de software para adaptarse a las necesidades del negocio. Consideran que el progreso de sus conocimientos gracias a la formación del catálogo de Frogames es muy apreciado y ha dado lugar a una mayor productividad, así como a ventajas monetarias para la empresa, además de agilizar los procesos de contratación.
# Solicitar Propuesta
# Ahorro de un 80% de  promedio en formación
# +100K€ ahorrados en costes de contratación por año/organización
# +2,25M€ de ingresos medios al año/organización
# POTENCIAMOS LAS EMPRESAS DESDE LA FORMACIÓN
# "Frogames ha sido fundamental para facilitar a nuestros empleados la rápida actualización y acceso a las nuevas tecnologías y herramientas para que todos puedan realizar su trabajo correctamente. Se trata responder a preguntas clave en nuestro negocio, como saber si alcanzamos nuestros objetivos, si cumplimos los plazos de producción y si respetamos los calendarios."
# Personal 4x veces más competente
# Un impresionante rendimiento proyectado del 492% en un periodo de 3 años.
# Los usuarios de Frogames consiguen de media un 12% más de productividad
# Se ahorran unas 4,8 horas extra de trabajo a la semana por empleado gracias a los métodos  y cursos online de Frogames.
# Ayudando a
# miles
# de personas de
# todos
# los niveles
# Los alumnos que aprenden con Frogames Formación experimentan un aumento medio del 27% en la productividad.
# Plan de trabajo personaliado
# "Gracias a Frogames, tenemos administradores y empleados más competentes. La fórmula de aprendizaje genera una mejora tecnológica y de actitudes sin precedentes. Nuestros empleados están dominando la capacidad de prestar atención y ser compasivos, hacer frente al agotamiento, que es un problema importante actualmente, y desarrollar la tenacidad y la resiliencia del equipo."
# Más volumen de negocios
# "Podemos conseguir mucho más volumen de negocios gracias a la formación que tenemos a tiempo gracias a Frogames. Podemos desarrollar un Plan de Aprendizaje esta semana con Frogames y tenerlo listo para la semana siguiente".
# Formar a nuestros empleados
# "No hemos podido  todos los puestos de los empleados que se han ido, así que así que hay habilidades que hay que cubrir. Frogames ha desempeñado un gran papel en términos de ser capaz de moverse con la naturaleza y el flujo de estas dinámicas necesidades".
# Aviso Legal
# Política de Privacidad
# Términos de Uso
# Política de Cookies
# Política de Redes Sociales
# FAQs
# Frogames Facebook
#                     (Abrir en una nueva ventana)
# Frogames Twitter
#                     (Abrir en una nueva ventana)
# Frogames Youtube
#                     (Abrir en una nueva ventana)
# © Copyright Frogames 2026
#
#
#
# Pagina de Premios
# Título de la Web:
# Premios
# Contenido de la Web:
# Ir al contenido principal
# Frogames
# Menú alternativo
# Menú
# Iniciar sesión
# Una formación valorada en el mundo entero
# Los
# Premios
# de Frogames Formación
# Conoce todos los premios que Frogames Formación y su equipo ha recibido por su desempeño y vocación volcada en la enseñanza digital
# Education and Training Awards
# Educación más innovadora de Europa 2023
# Premio a la educación online más innovadora de datos y habilidades digitales 2023 - Europa
# Ver el premio
# The Silicon Review
# Uno de los 30 líderes más inspiradores para seguir en 2023
# Premio a Juan Gabriel Gomila, como uno de los líderes más inspiradores del año 2023 por su trayectoria profesional
# Ver el premio
# Docencia
# Certificado de Excelencia 2023
# Certificado de Excelencia en la formación del catálogo de Frogames
# Ver las valoraciones
# CIO Bulletin
# Una de las 50 empresas más innovadoras para seguir en 2023
# Premio a Frogames Formación por ser una de las empresas más innovadoras del 2023.
# Ver el premio
# Aviso Legal
# Política de Privacidad
# Términos de Uso
# Política de Cookies
# Política de Redes Sociales
# FAQs
# Frogames Facebook
#                     (Abrir en una nueva ventana)
# Frogames Twitter
#                     (Abrir en una nueva ventana)
# Frogames Youtube
#                     (Abrir en una nueva ventana)
# © Copyright Frogames 2026
#
#
#
# Pagina de Afiliados
# Título de la Web:
# Afiliados
# Contenido de la Web:
# Ir al contenido principal
# Frogames
# Menú alternativo
# Menú
# Iniciar sesión
# Programa de Afiliación de Frogames
# Conviértete en afiliado y gana dinero vendiendo nuestros cursos y suscripciones a tus seguidores
# Conoce nuestro programa de afiliados
# Si tienes una comunidad, canal o página web, esto te interesa
# Si estás leyendo esta página es por alguna de estas tres razones:
# Has realizado algún curso en Frogames Formación y te gusta nuestra forma de enseñar.
# Piensas que hay personas de tu entorno a las que les puede interesar los cursos o rutas de Frogames Formación.
# A nosotros nos gustaría que te unieras a nuestro programa de afiliados y que empieces a ganar dinero con tus ventas.
# Si en cualquier momento tienes dudas, puedes escribir a
# [email protected]
# y estaremos encantados de ayudarte.
# Conoce nuestro programa de afiliados
# ¿Qué es el programa de afiliados de Frogames?
# El programa de afiliados de Frogames es un programa de afiliados solo para mis alumnos y miembros seleccionados donde puedes obtener una comisión de hasta el 50% del valor de la venta.
# ¿Qué plataforma vamos a utilizar?
# La plataforma que vamos a utilizar en este programa de afiliados es la nuestra, Frogames Formación que utiliza la tecnología de Thinkific para la asignación de cookies y el seguimiento del tráfico.
# ¿Qué modelo de atribución utiliza?
# El modelo de atribución de comisión del producto es el del
# registro del usuario
# (en caso de que un alumno venga referido por más de un afiliado, se asigna la comisión al afiliado que haya conseguido que el usuario se registrara inicialmente en la plataforma).
# A partir de ese momento, cualquier compra que el usuario realice en la plataforma se atribuirán al afiliado de registro.
# ¿Y cuándo y cómo puedo cobrar mi dinero?
# Las comisiones te las asignará el sistema de forma automática en tu cuenta cada vez que se produzca una venta a través de tu enlace. Para recibir tu dinero en tu cuenta de Paypal, lo podrás solicitar trimestralmente siempre y cuando superes el mínimo requerido de 100€ para recibir la transferencia.
#
# Para ello, deberás generar trimestralmente
# una factura que incluya el importe a percibir
# así como tus datos fiscales y los de Frogames que te facilitaremos.
# ¿Y si un estudiante se apunta a un curso gratis?
# Es de hecho una muy buena estrategia. El sistema registrará como afiliado, aquel que haya conseguido que el usuario se registre en frogames. Desde ese momento, cualquier venta que lleve a cabo el estudiante, será asignada al afiliado en cuestión, sin importar que se registrara por un curso gratuito de la plataforma.
# ¿Cuándo están disponibles para la venta los cursos?
# Nuestros cursos siempre están disponibles y abiertos a que nuevos alumnos puedan apuntarse y llevarlo a cabo.
# ¿Qué comisión me voy a llevar?
# La comisión es variable: llévate hasta un 50% sobre el precio de compra (deduciendo los impuestos del país del comprador, si los hay, y la comisión del método de pago).
#
# Más abajo tienes explicados los diferentes niveles de afiliado, y la subida o descenso de un nivel a otro en función de tus resultados trimestrales.
# ¿Cómo se asignarán mis ventas de afiliado?
# El parámetro del afiliado va en la URL, así que asegúrate siempre de incluir el tuyo para que la asignación sea para ti!
# A partir de ese momento, todos los cursos y suscripciones que ese usuario adquiera en frogames, se asignarán al afiliado que haya conseguido el registro en primer lugar.
# ¿Puedo utilizar mis ingresos para comprar cursos?
# Por supuesto, si es un problema acceder a Paypal o generar una factura trimestral, puedes decidir cambiar tus ingresos generados como afiliado por nuevos cursos / suscripciones de la plataforma de Frogames.
# EL SISTEMA DE AFILIADOS
# Un plan a tu medida en función de tu propio rendimiento
# Nuestro sistema te recompensará cuánto más estudiantes traigas y más ventas generes. Al finalizar cada trimestre, se evaluará si cumples las condiciones para promocionar de categoría de afiliado.
# El plan de Afiliados
# Afiliado básico - 15%
# Cuando te inscribes en el programa de afiliados de Frogames, empiezas aquí
# Mostrar condiciones
# Ocultar condiciones
# ¿Qué porcentaje de la venta me llevo?
# 15% del valor de la venta
# %
# ¿Cómo accedo al plan?
# Nos tienes que enviar un correo electrónico a
# [email protected]
# solicitando ser afiliado e indicando tu correo de inscripción en Frogames Formación
# ?
# ¿Cómo me mantengo en el plan?
# Te mantendrás en el plan de afiliado básico mientras no cumplas las condiciones para ascender a los siguientes niveles o hasta que decidas darte de baja del programa.
# @
# Afiliado de Bronce - 25%
# Consigue el objetivo trimestral o conviértete en suscriptor de la rana de bronce
# Mostrar condiciones
# Ocultar condiciones
# ¿Qué porcentaje de la venta me llevo?
# 25% del valor de la venta
# %
# ¿Cómo accedo al plan?
# Una vez que eres afiliado de Frogames, supera el umbral de 100€ de venta durante el trimestre anterior, o conviértete tu mismo en suscriptor de bronce
# ?
# ¿Cómo me mantengo en el plan?
# Para mantenerte tu estatus de afiliado de bronce debes cumplir trimestralmente el objetivo mínimo o seguir siendo suscriptor de bronce; en caso contrario bajarás al nivel de afiliado básico.
# @
# Afiliado de plata - 35%
# Consigue el objetivo trimestral o conviértete en suscriptor de la rana de plata
# Mostrar condiciones
# Ocultar condiciones
# ¿Qué porcentaje de la venta me llevo?
# 35% del valor de la venta
# %
# ¿Cómo accedo al plan?
# Una vez que eres afiliado de Frogames, supera el umbral de 350€ de venta durante el trimestre anterior, o conviértete tu mismo en suscriptor de plata
# ?
# ¿Cómo me mantengo en el plan?
# Para mantenerte tu estatus de afiliado de plata debes cumplir trimestralmente el objetivo mínimo o seguir siendo suscriptor de plata; en caso contrario bajarás al nivel de afiliado de bronce.
# @
# Afiliado de oro - 50%
# Consigue el objetivo trimestral o conviértete en suscriptor de la rana de oro
# Mostrar condiciones
# Ocultar condiciones
# ¿Qué porcentaje de la venta me llevo?
# 50% del valor de la venta
# %
# ¿Cómo accedo al plan?
# Una vez que eres afiliado de Frogames, supera el umbral de 1000€ de venta durante el trimestre anterior, o conviértete tu mismo en suscriptor de oro
# ?
# ¿Cómo me mantengo en el nivel?
# Para mantenerte tu estatus de afiliado de oro debes cumplir trimestralmente el objetivo mínimo o seguir siendo suscriptor de oro; en caso contrario bajarás al nivel de afiliado de plata.
# @
# ¿Cómo darse de alta en el sistema de afiliados?
# Solamente envía un email con tus datos, y en 24h serás afiliado
# Como ya hemos comentado en los puntos anterior, todo el proceso de gestión de afiliación, seguimiento de resultado y solicitudes de cobro se realizarán a través de la plataforma de Frogames. Una vez que tengas cuenta en nuestra plataforma, debes enviar un email a
# [email protected]
# indicándonos tu email de registro y que deseas convertirte en afiliado nuestro.
# Inscribirme ahora
# ¿Cómo encontrar los enlaces a compartir?
# Desde tu portal de frogames, tendrás la nueva página de afiliados.
# Desde la barra de menús, arriba a la derecha haz click en 'Tu nombre' > Afiliados para acceder al menú desde donde podrás seleccionar curso, creatividad y estilo. El sistema te generará automáticamente el código URL e imágenes que podrás utilizar para atraer nuevos visitantes a Frogames como afiliado.
#
# ¡Cuantos más cursos compartas, más opciones de venta generarás!
# Ir al panel de afiliados
# Aviso Legal
# Política de Privacidad
# Términos de Uso
# Política de Cookies
# Política de Redes Sociales
# FAQs
# Frogames Facebook
#                     (Abrir en una nueva ventana)
# Frogames Twitter
#                     (Abrir en una nueva ventana)
# Frogames Youtube
#                     (Abrir en una nueva ventana)
# © Copyright Frogames 2026
#
#
#
# Convalidación de Cursos
# Título de la Web:
# Convalidación de Cursos de Udemy
# Contenido de la Web:
# Ir al contenido principal
# Frogames
# Menú alternativo
# Menú
# Iniciar sesión
# Empezar ahora
# <!-- identifier y2d-cIBSB1Y https://youtu.be/y2d-cIBSB1Y -->
#
#
#                 <div class="embed-responsive embed-responsive-16by9">
#     <div id="youtube-y2d-cIBSB1Y">
#       <iframe width="640" height="360" src="https://www.youtube.com/embed/y2d-cIBSB1Y" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
#     </div>
#   </div>
# 4
# Cómo convalidar tus diploma de Udemy
# (00:00)
# Proceso de convalidación
# Enviar los recibos de compra
# Enviar los certificados en PDF
# ¡Ya casi lo tienes!
# FROGAMES TE CERTIFICA TODO LO QUE HAYAS APRENDIDO
# Elige solamente el
# certificado blockchain
# o aprovecha el combo de la convalidación más el
# PDF personalizado
# Convierte todos tus cursos de Frogames adquiridos en Udemy a certificados blockchain con un solo click.
# * Condiciones: los cursos comprados deben haber sido adquiridos en Udemy en un periodo superior a 30 días cuando solicites la convalidación. En caso contrario, no podremos proceder a convalidarte el curso hasta pasado ese tiempo.
# Convalidación Blockchain
# €14,99
# Comprar Ahora
# Certificado Blockchain + PDF
# €24,99
# Comprar Ahora
# *Precio de convalidación en oferta temporalmente. El precio original de cada convalidación es de 20€, impuestos incluidos.
# Por tu seguridad, todos los pedidos se procesan en un servidor seguro.
# Aviso Legal
# Política de Privacidad
# Términos de Uso
# Política de Cookies
# Política de Redes Sociales
# FAQs
# Frogames Facebook
#                     (Abrir en una nueva ventana)
# Frogames Twitter
#                     (Abrir en una nueva ventana)
# Frogames Youtube
#                     (Abrir en una nueva ventana)
# © Copyright Frogames 2026
#
#
#
# Cursos
# Título de la Web:
#  Cursos online para todos los niveles - Frogames
# Contenido de la Web:
# Ir al contenido principal
# Frogames
# Menú alternativo
# Menú
# Iniciar sesión
# Productos
# Alain Nicolás
# Albert Gris
# Ana Vassallo
# Android
# Antonio Maria Aja Escudero
# Arnau Mir
# Benjamin Miró
# Blender
# Blockchain
# Business Intelligence
# C#
# Carlos Bastida
# Cursos de Idiomas
# Data Science
# Denis Panjuta
# Desarrollo de Videojuegos
# Difícil
# Emprendimiento
# Excel
# Experto
# Extras para Suscriptores
# Fácil
# Gilvard Pérez
# Habilidades Blandas
# Herramientas de Desarrollo
# Inteligencia Artificial
# iOS
# Java
# Joan Amengual
# Joan Pont
# John Morales
# Jose Antonio Corral Fiestas
# Juan Gabriel Gomila
# Kotlin
# Libros
# Ligency
# Lucas Inglese
# Machine Learning
# María José Hidalgo Poderoso
# Mariano Sosa
# María Santos
# Marketing
# Matemáticas Avanzadas
# Matemáticas desde Cero
# Mateu Mercer
# Media
# Música
# Oak Academy
# Pedro Daniel Alcalá
# Power BI
# Programación
# Programación de Videojuegos
# Programación Web
# Proyectos Finales
# Python
# R
# React
# Reporting
# Ricardo Alberich
# Rocío Chavez
# Rutas Completas
# Sergio Domínguez
# Solidity
# SQL
# Suscripciones
# Swift
# Tableau
# Todos los Cursos
# TradeStation
# Trading Algorítmico
# Unity
# Unity 2D
# Unity 3D
# Unreal Engine
# Yimmy Eman
# Buscar
# ¡Pedido anticipado!
# Arqueología del Videojuego: Historia, Análisis Crítico y ADN del Diseño
# €19,99
# Python para Inteligencia Artificial desde Cero: De Principiante a Ingeniero Pro en IA
# Gratis
# Introducción al Machine Learning con Python
# 5.0
# valoración media
# (30 reseñas)
# Nivel Fácil
# Gratis
# Fundamentos de Matemáticas para Machine Learning
# 5.0
# valoración media
# (20 reseñas)
# Nivel Fácil
# €79,99
# Fundamentos Intermedios de Matemáticas para Machine Learning
# 5.0
# valoración media
# (21 reseñas)
# Nivel Fácil
# €79,99
# Una semana de ciencia de datos en Python
# 5.0
# valoración media
# (24 reseñas)
# Nivel Fácil
# €79,99
# 1
# 2
# 3
# …
# 38
# …
# Certificados
# Rutas
# Suscripciones
# Blog
# Podcast
# Iniciar sesión
# Todos los Cursos
# ¡Pedido anticipado!
# Arqueología del Videojuego: Historia, Análisis Crítico y ADN del Diseño
# 0
# (0)
# 47
# Python para Inteligencia Artificial desde Cero: De Principiante a Ingeniero Pro en IA
# 0
# (0)
# 46
# Introducción al Machine Learning con Python
# 5.0
# (30)
# 27
# Fundamentos de Matemáticas para Machine Learning
# 5.0
# (20)
# 121
# Fundamentos Intermedios de Matemáticas para Machine Learning
# 5.0
# (21)
# 102
# Una semana de ciencia de datos en Python
# 5.0
# (24)
# 155
# Fundamentos Avanzados de Matemáticas para Machine Learning
# 5.0
# (12)
# 93
# Machine Learning de la A a la Z
# 5.0
# (39)
# 304
# Probabilidad y Estadística aplicada a Negocios y Empresas
# 5.0
# (20)
# 162
# Curso completo de R para Data Science con Tidyverse
# 5.0
# (23)
# 226
# Curso completo de Machine Learning: Data Science con RStudio
# 5.0
# (23)
# 237
# Tratamiento de datos en Python: ETL de cero a experto
# 5.0
# (31)
# 84
# Curso completo de Machine Learning: Data Science en Python
# 5.0
# (33)
# 235
# Aprende a analizar los datos del COVID19 con R y Python
# 5.0
# (21)
# 59
# Data Science aplicado a Negocios | 6 Casos de Estudio Reales
# 5.0
# (24)
# 79
# Domina Kotlin desde Cero: Software con Estándares de Calidad
# 5.0
# (20)
# 163
# Domina Android desde cero con Kotlin, Compose y Gemini AI
# 5.0
# (16)
# 692
# Fundamentos de Kotlin con Android desde cero
# 5.0
# (29)
# 163
# Introducción al Desarrollo de Apps para Android desde Cero
# 5.0
# (22)
# 105
# Control de versiones con Git, Github, BitBucket y SourceTree
# 5.0
# (19)
# 68
# Adaptadores en Android con Kotlin de 0 a 100
# 5.0
# (27)
# 70
# Bootcamp de Desarrollo con Android
# 5.0
# (20)
# 228
# Curso de Android 13 con Kotlin: Intensivo y práctico 2023
# 5.0
# (18)
# 452
# Prompt Engineering: Crea Apps Android 100% con Gemini IA
# 5.0
# (6)
# 71
# Crea tus primeras apps en Android con Kotlin
# 5.0
# (21)
# 165
# Crea 7 apps para Android N
# 5.0
# (20)
# 137
# Monetiza tus apps de Android, sistema de pagos con PayPal
# 5.0
# (19)
# 41
# Profesional en Material Design/Theming para Android, UX y UI
# 5.0
# (17)
# 206
# Master avanzado de Android: Patrones de programación con Kotlin
# 4.9
# (17)
# 147
# Master avanzado de Android: patrones de programación
# 5.0
# (20)
# 134
# Google Maps SDK para Android y Kotlin de la A a la Z
# 5.0
# (20)
# 129
# Firebase para Android con Kotlin de la A a la Z
# 5.0
# (23)
# 252
# Experto en Firebase para Android con Java y MVP
# 5.0
# (18)
# 260
# Curso completo de Corrutinas y Flow con Android y Kotlin
# 5.0
# (20)
# 87
# Android Hilt, Inyección de Dependencias con Kotlin y Jetpack
# 5.0
# (20)
# 132
# Jetpack Compose desde cero, migra tus vistas de Android XML
# 5.0
# (20)
# 113
# 1
# 2
# 3
# …
# 6
# …
# Aviso Legal
# Política de Privacidad
# Términos de Uso
# Política de Cookies
# Política de Redes Sociales
# FAQs
# Frogames Facebook
#                     (Abrir en una nueva ventana)
# Frogames Twitter
#                     (Abrir en una nueva ventana)
# Frogames Youtube
#                     (Abrir en una nueva ventana)
# © Copyright Frogames 2026

# %%
system_prompt = "Eres un asistente que analiza el contenido de varias páginas relevantes del sitio web de una empresa\
y crea un folleto breve sobre la empresa para posibles clientes, inversores y nuevos empleados. Responde en formato Markdown.\
Incluye detalles sobre la cultura de la empresa, los clientes, las carreras/empleos y los cursos/packs para futuros empleos si tienes la información."

# O descomenta las líneas a continuación para obtener un folleto más humorístico: esto demuestra lo fácil que es incorporar el "tono":

system_prompt = "Eres un asistente que analiza el contenido de varias páginas relevantes del sitio web de una empresa \
y crea un folleto breve, divertido y gracioso sobre la empresa para posibles clientes, inversores y nuevos empleados. Responde en formato Markdown.\
Incluye detalles sobre la cultura de la empresa, los clientes y los cursos/packs para futuros empleos si tienes la información."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"Estás mirando una empresa llamada: {company_name}\n"
    user_prompt += f"Aquí se encuentra el contenido de su página de inicio y otras páginas relevantes; usa esta información para crear un breve folleto de la empresa en Markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:20_000] # Truncar si tiene más de 20.000 caracteres
    return user_prompt

# %%
get_brochure_user_prompt("FROGAMES", "https://cursos.frogamesformacion.com")
# Out:
# Links encontrados: {'links': [{'type': 'Pagina Acerca de', 'url': 'https://cursos.frogamesformacion.com/pages/instructores'}, {'type': 'Pagina de Certificaciones', 'url': 'https://cursos.frogamesformacion.com/pages/certificaciones'}, {'type': 'Pagina de Cursos', 'url': 'https://cursos.frogamesformacion.com/collections'}, {'type': 'Pagina de Rutas', 'url': 'https://cursos.frogamesformacion.com/pages/rutas'}, {'type': 'Pagina de Nuestros Clientes', 'url': 'https://cursos.frogamesformacion.com/pages/nuestros-clientes'}, {'type': 'Pagina de Premios', 'url': 'https://cursos.frogamesformacion.com/pages/premios'}, {'type': 'Pagina para Empresas', 'url': 'https://cursos.frogamesformacion.com/pages/frogames-para-empresas'}, {'type': 'Pagina de Afiliados', 'url': 'https://cursos.frogamesformacion.com/pages/afiliados'}, {'type': 'Cursos de Convalidación', 'url': 'https://cursos.frogamesformacion.com/courses/convalidacion-de-cursos-de-udemy'}, {'type': 'Pagina Principal', 'url': 'https://cursos.frogamesformacion.com'}]}
# "Estás mirando una empresa llamada: FROGAMES\nAquí se encuentra el contenido de su página de inicio y otras páginas relevantes; usa esta información para crear un breve folleto de la empresa en Markdown.\nLanding page:\nTítulo de la Web:\nFrogames\nContenido de la Web:\nIr al contenido principal\nFrogames\nMenú alternativo\nMenú\nIniciar sesión\nGanadora del premio 'Enseñanza online de datos y competencias digitales más innovadora de Europa, 2023'\nPasión por\naprender\ncon los\nmejores\nEn Frogames Formación te ayudamos a convertirte en todo un experto en: Programación de Videojuegos, Inteligencia Artificial, Machine Learning, Desarrollo de Apps, Data Science y mucho más.\nAprende mientras te diviertes\nCursos, Rutas y Suscripciones\nCertificados de finalización\nQué encontrarás\ndentro\nde Frogames\nCursos online y formación de calidad para toda la família\nRutas temáticas\nRutas organizadas para que aprendas paso a paso, subiendo cada escalón e incrementando tus conocimientos adquiridos\nInstructores Expertos\nCon un equipo de profesionales y expertos en la materia que te acompañará a lo largo de todo el aprendizaje en la plataforma\nCertificados blockchain\nTítulos verificados por blockchain para cada habilidad que aprendas, listos para compartir en tus redes sociales y mejorar tu CV\nConstantes actualizaciones\nCada semana añadiremos nuevos o actualizaremos nuestros cursos. Extenderemos las rutas con actualizaciones periódicas.\nLos\ncursos\ntop\nNuevos Lanzamientos\nLos más vendidos\nTodos los Cursos\nPrompt Engineering: Crea Apps Android 100% con Gemini IA\n5.0\n(6)\n71\nIngeniería de IA y MLOps en Producción: IA Generativa y Agéntica a Gran Escala con AWS, GCP y Azure\n5.0\n(8)\n154\nAnálisis de forecasting con Power BI\n5.0\n(10)\n7\nAnalítica avanzada con Power BI\n5.0\n(10)\n20\nPower BI: Mi primer proyecto Fitness Life\n5.0\n(11)\n13\nInforme Ejecutivo de IA Generativa 2025: LLMs para Líderes\n5.0\n(12)\n21\nAprende Matemáticas desde Cero - Geometría Analítica\n5.0\n(9)\n490\nCurso Completo de Ingeniería de Agentes de IA (2025)\n5.0\n(18)\n175\nDomina Android desde cero con Kotlin, Compose y Gemini AI\n5.0\n(16)\n692\nDomina las Interfaces de Usuario en Unity 6: De Cero a Experto en UI/UX Interactiva\n5.0\n(18)\n61\nFundamentos Avanzados de Matemáticas para Machine Learning\n5.0\n(12)\n93\nInteligencia Artificial en Flutter con Firebase AI\n5.0\n(14)\n39\nAprende Matemáticas desde Cero - Aritmética\n5.0\n(35)\n345\nGuía definitiva de ChatGPT: domina la productividad con ejemplos reales\n5.0\n(22)\n82\n15 días de Power BI - El bootcamp completo de Power BI\n5.0\n(30)\n199\nMachine Learning de la A a la Z\n5.0\n(39)\n304\nCurso de desarrollo de videojuegos con Unity 2021\n5.0\n(30)\n339\nTrading algorítmico para principiantes: de cero a héroe\n5.0\n(28)\n102\nCurso Completo de Unreal Engine 5\n5.0\n(26)\n128\nCurso completo de Python de la A a la Z\n5.0\n(57)\n498\nMás de\n500.000\nestudiantes de\ntodos\nlos niveles satisfechos\nNuestros estudiantes han desarrollado sus habilidades gracias a nuestros cursos. Estas son algunas de sus historias.\nMe gusta aprender en Frogames porque sus cursos son especializados\nRealmente prácticos, muy avanzados en contenido lo que es un reto muy emocionante. Estoy aprendiendo las bases matemáticas de los videojuegos, lo que pocos enseñan o solamente lo hacen superficialmente, siempre que ingreso a la plataforma estoy con una sonrisa de oreja a oreja\nEdwyn Mendoza\nMe encanta ser parte de una comunidad donde se aprende, crece y también se disfruta.\nSiempre estaré eternamente agradecida de todas las herramientas que Frogrames me ha entregado tan generosamente como persona y profesional. Lo recomiendo sin duda alguna con los ojos cerrados.\nJaviera Constanza Vallejos Jara\nDesde el primer momento elegí la suscripción anual por todas las ventajas que ofrece.\nSabía que sería una decisión acertada desde el primer momento. Ahora puedo acceder a todos los cursos que quiero y con nuevo co ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("FROGAMES", "https://cursos.frogamesformacion.com")
# Out:
# Links encontrados: {'links': [{'type': 'Página Principal', 'url': 'https://cursos.frogamesformacion.com/'}, {'type': 'Rutas de Cursos', 'url': 'https://cursos.frogamesformacion.com/pages/rutas'}, {'type': 'Página de Instructores', 'url': 'https://cursos.frogamesformacion.com/pages/instructores'}, {'type': 'Certificaciones', 'url': 'https://cursos.frogamesformacion.com/pages/certificaciones'}, {'type': 'Nuestros Clientes', 'url': 'https://cursos.frogamesformacion.com/pages/nuestros-clientes'}, {'type': 'Frogames para Empresas', 'url': 'https://cursos.frogamesformacion.com/pages/frogames-para-empresas'}, {'type': 'Premios', 'url': 'https://cursos.frogamesformacion.com/pages/premios'}, {'type': 'Convalidación de Cursos de Udemy', 'url': 'https://cursos.frogamesformacion.com/courses/convalidacion-de-cursos-de-udemy'}, {'type': 'Página de Cursos', 'url': 'https://cursos.frogamesformacion.com/collections'}, {'type': 'Afiliados', 'url': 'https://cursos.frogamesformacion.com/pages/afiliados'}, {'type': 'Opiniones en Trustpilot', 'url': 'https://es.trustpilot.com/review/cursos.frogamesformacion.com'}, {'type': 'Opiniones en Emagister', 'url': 'https://www.emagister.com/opiniones-frogames-formacion-opincen-1171758.htm'}, {'type': 'Artículos sobre Frogames Formación', 'url': 'https://thesiliconreview.com/magazine/profile/solidifying-position-global-online-education-platform-juan-gabriel-frogames-formacin'}, {'type': 'Calidad de Cursos en CIO Bulletin', 'url': 'https://www.ciobulletin.com/magazine/frogames-formacion-quality-spanish-language-courses'}]}
# ```markdown
# # 🐸 Frogames: ¡Donde Aprender Es un Juego!
#
# ¡Bienvenido al mundo de Frogames! 🚀 Si estás buscando aprender sobre Programación de Videojuegos, Inteligencia Artificial o simplemente deseas ser un maestro del Data Science, ¡has llegado al lugar correcto! No solo quiero que aprendas, ¡sino que te diviertas haciéndolo! 🎮
#
# ---
#
# ## 🎉 ¿Por qué Elegir Frogames?
#
# ### *Premios y Más Premios* 🏆
# - Ganadores del premio a la **"Enseñanza online de datos y competencias digitales más innovadora de Europa, 2023".** Así, sí que se empieza con buen pie, ¿no?
#
# ### *Cursos que Hacen Sonreír* 😄
# Desde **Prompt Engineering** hasta **Desarrollo de Videojuegos** y **Machine Learning**, hay un curso para cada gusto frustrado de un nerd apasionado. ¡Y si no usas la sonrisa de oreja a oreja después de un curso, te devolvemos el... ah, espera, eso no lo hacemos!
#
# #### Cursos Destacados:
# - **Crea Apps Android 100% con Gemini IA** 💡
# - **Curso Completo de Python de la A a la Z** 🐍
# - **Trading algorítmico para principiantes: de cero a héroe** 🦸‍♂️
#
# ## ✅ Lo Que Ofrecemos
# - **Rutas Temáticas**: Aprender es como una aventura! Sabemos que subir escalones puede dar miedo, así que lo hacemos paso a paso.
# - **Instructores Expertos**: ¡Nuestros instructores son como esos maestros de Harry Potter, pero sin el sombrero! Aportan sabiduría y alegría (¡y sin los hechizos peligrosos!).
# - **Certificados Blockchain**: ¡Porque tus logros merecen ser compartidos en tus redes sociales! 📜
# - **Actualizaciones Constantes**: ¡Siempre estamos renovando! Como tus platos favoritos, queremos que tengas siempre el menú fresco.
#
# ---
#
# ## 🌍 ¡Únete a Nuestra Comunidad!
#
# Más de **500,000 estudiantes** de todos los rincones del mundo están disfrutando y desarrollando sus habilidades con nosotros. Estos son algunos de sus testimonios:
#
# > *"Frogames es el lugar adecuado para aprender en un ambiente amigable y divertido!"* - **Eulogio**
#
# > *"Luego de comenzar aquí, no puedo dejar de aprender. Es como tener un buffet de conocimiento!"* - **Toni**
#
# ## 🕹️ La Suscripción Rana: ¡Una Opción Irresistible! 🐸
# - **Rana de Oro**: Todo el acceso a 224 cursos por solo **€349 al año**.
# - **Rana de Bronce**: Acceso mensual a todos los cursos por **€39/mes**.
#
# ---
#
# ### 🎓 ¡Cualquiera Puede Aprender!
# Sin importar tu edad o fondo, ¡Frogames te tiene cubierto! Desde niños hasta adultos, aquí hay un camino para todos. ¿Quieres convertirte en el Bruce Wayne de la tecnología? ¡Comienza ya!
#
# ### 💼 ¿Buscas Trabajo?
# Si eres un apasionado de la enseñanza y tienes una audiencia, ¡Frogames también tiene un sistema de afiliados que te da recompensas por tus ventas! 💸
#
# ---
#
# # ¡Comienza tu Aventura en Frogames!
# **¿Listo para unirte a la familia Frogames? 🐸✨ Mereces aprender y jugar al mismo tiempo. ¡Házlo ya!**
#
# [Obtén tu curso gratis](#) y descubre todo lo que Frogames tiene para ofrecerte.
# ```
#
# Este folleto expresa el espíritu divertido y acogedor de Frogames, invitando a todos a involucrarse en su experiencia de aprendizaje sin dejar de ser informativo y atractivo.

# %% [markdown]
# create_brochure("Frogames Formación", "https://cursos.frogamesformacion.com")

# %% [markdown]
# ## Por último, una pequeña mejora
#
# Con un pequeño ajuste, podemos cambiar esto para que los resultados se transmitan desde OpenAI,
# con la animación de máquina de escribir habitual

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %% [markdown]
# stream_brochure("URJC", "https://servicios.urjc.es/practicas/ofertas/")

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Links encontrados: {'links': [{'type': 'Pagina Sobre nosotros', 'url': 'https://huggingface.co/'}, {'type': 'Pagina de Empleo', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'Pagina de Cursos', 'url': 'https://huggingface.co/learn'}, {'type': 'Pagina de Precios', 'url': 'https://huggingface.co/pricing'}, {'type': 'Pagina de Espacios', 'url': 'https://huggingface.co/spaces'}, {'type': 'Pagina de Modelos', 'url': 'https://huggingface.co/models'}, {'type': 'Pagina de Conjuntos de Datos', 'url': 'https://huggingface.co/datasets'}, {'type': 'Blog', 'url': 'https://huggingface.co/blog'}]}
# # 🤗 Hugging Face: The Future of AI Awaits You! 🌟
#
# ¡Bienvenido! Prepara tus abrazos y tu mejor sonrisa porque en Hugging Face estamos construyendo la comunidad de IA que cambiará el mundo. 🎉
#
# ---
#
# ## 🤖 ¿Quiénes somos?
#
# Hugging Face no es solo un nombre bonito, sino una plataforma donde los apasionados de **Machine Learning** (ML) se reúnen para colaborar, compartir modelos, datasets, y aplicaciones como si fueran galletas en un buffet. ¡Estamos hablando de más de **2 millones de modelos** listos para que los explores! 🏆
#
# ### 🎈 Misión:
# - **Construir el futuro de la IA**: Porque un futuro sin IA es como un café sin cafeína: ¡simplemente no funciona!
#
# ---
#
# ## 🌍 Nuestros Clientes
#
# Más de **50,000 organizaciones** ya confían en nosotros, incluyendo:
# - **Amazon**, **Google**, **Microsoft** y hasta el pequeño **Grammarly** (quien nunca se siente pequeño en el mundo de la gramática). 📈
#
# ---
#
# ## 💡 Cursos para Novatos y Expertos
#
# ¡Te presentamos nuestra gran selección de cursos!
# * **LLM Course:** Aprende todo sobre modelos de lenguaje grandes (¡sin necesitar una máquina del tiempo!).
# * **Deep RL Course:** Dedicado a los valientes que quieren enfrentar el refuerzo profundo (militar no incluido).
# * **Robotics Course:** ¡Construye robots! (Sin riesgo de Skynet... aún).
# * **ML for Games Course:** Porque tus juegos también merecen un toque de inteligencia... artificial.
#
# ¡Esos son solo algunos ejemplos! Hay más donde esos vinieron 😄.
#
# ---
#
# ## 💵 Precios Flexibles
#
# * **Pro Account:** $9/mes - ¡Obtén acceso a un mundo de posibilidades sin que tu billetera se queje!
# * **Team Plan:** Solo $20/usuario/mes - ¡Ideal para colaborar con tus colegas! 🧑‍🤝‍🧑
# * **Enterprise:** ¡El rey de los planes! Comienza a $50/usuario/mes con beneficios que te harán sentir como un verdadero CEO. 👑
#
# ---
#
# ## 🌟 La Cultura de Hugging Face
#
# Nuestra cultura es abierta, inclusiva y un poco... ¡quirky! 🤪 Queremos que puedas expresar tu genialidad sin temor. Si alguna vez has sentido que tus modelos son tus amigos, ¡bienvenido a casa! 🏠
#
# ---
#
# ## 🚀 Prepárate para el Futuro
#
# ¿Estás listo para unirte a nosotros y ser parte de algo grande? ¡No olvides registrarte y empezar a colaborar! Con Hugging Face, el futuro no solo es brillante, es también **divertido**. 🙌
#
# ---
#
# ### [¡Explora nuestra plataforma!](https://huggingface.co) 📲
#
# Para más detalles sobre formación, precios, y cómo construir la mejor comunidad de IA, ¡visita nuestra web! ¡Vamos a construir el futuro juntos, un abrazo a la vez! 🤗

# %%
stream_brochure("Frogames Formación", "https://cursos.frogamesformacion.com")
# Out:
# Links encontrados: {'links': [{'type': 'Pagina Sobre nosotros', 'url': 'https://cursos.frogamesformacion.com/pages/instructores'}, {'type': 'Pagina de Certificaciones', 'url': 'https://cursos.frogamesformacion.com/pages/certificaciones'}, {'type': 'Pagina de Nuestros Clientes', 'url': 'https://cursos.frogamesformacion.com/pages/nuestros-clientes'}, {'type': 'Pagina para Empresas', 'url': 'https://cursos.frogamesformacion.com/pages/frogames-para-empresas'}, {'type': 'Pagina de Premios', 'url': 'https://cursos.frogamesformacion.com/pages/premios'}, {'type': 'Pagina de Cursos', 'url': 'https://cursos.frogamesformacion.com/collections'}, {'type': 'Pagina de Afiliados', 'url': 'https://cursos.frogamesformacion.com/pages/afiliados'}, {'type': 'Pagina de Cursos Convalidación', 'url': 'https://cursos.frogamesformacion.com/courses/convalidacion-de-cursos-de-udemy'}]}
# # 🎉 Bienvenido a Frogames Formación 🎮
#
# ¡La plataforma educativa que convierte a sus estudiantes en expertos mientras se divierten! 🥳
#
# ### 🏆 **Premios y Reconocimientos**
# Ganadores del premio **Enseñanza Online de Datos y Competencias Digitales más Innovadora de Europa, 2023**. ¡Y eso es solo el comienzo!
#
# ### 🚀 **¿Qué ofrecemos?**
# En Frogames Formación te ayudamos a convertirte en un maestro de:
# - **Programación de Videojuegos**
# - **Inteligencia Artificial**
# - **Machine Learning**
# - **Desarrollo de Apps**
# - **Data Science**
# - ¡Y mucho más!
#
# ### 🧠 **Aprende mientras te diviertes**
# - **Cursos Online:** Desde análisis de datos hasta desarrollo de videojuegos, ¡tenemos algo para todos!
# - **Rutas Temáticas:** Apila tus conocimientos paso a paso como si fuera un juego de plataformas.
# - **Instructores Expertos:** Con un equipo increíble que te guiará en cada nivel de tu aventura formativa.
# - **Certificados Blockchain:** ¡Demuestra tus logros con un toque digital y hace que tu CV brille más que un Pokémon legendario!
#
# ### 🎓 **Nuestros Cursos Top**
# Aquí algunos de los favoritos de nuestros estudiantes:
# - **Prompt Engineering:** Crea Apps Android 100% con Gemini IA (⭐⭐⭐⭐⭐)
# - **Machine Learning de la A a la Z:** Desde novato hasta experto en un solo curso (⭐⭐⭐⭐⭐)
# - **Curso de Desarrollo de Videojuegos con Unity 2021:** ¡Haz el juego de tus sueños! (⭐⭐⭐⭐⭐)
#
# ### 🌐 **Nuestra Comunidad**
# Más de **500.000 estudiantes** aprendiendo y creciendo juntos. ¡Escucha lo que dicen!
# > "Me encanta aprender en Frogames porque sus cursos son especializados y realmente prácticos." - Edwyn M.
# > "Un lugar donde se aprende, crece y se disfruta." - Javiera C.
#
# ### 👩‍🏫 **Conoce a Nuestros Super Instructores**
# - **Juan Gabriel Gomila:** CEO y creador de esta maravillosa odisea educativa.
# - **María Santos:** Matemática y creadora de historias que siguen a tus sueños.
# - **El equipo Ligency:** ¡Éxitos en su currículum respaldan su talento!
#
# ### 💼 **¡Y si quieres trabajar con nosotros!**
# Conviértete en un afiliado y ¡obtén recompensas por cada estudiante que traigas! 🤑
#
# ### 📈 **Frogames para Empresas**
# Ofrecemos formación para empresas que quiere potenciar su talento humano (¡y su productividad!). Disfruta de descuentos especiales y un catálogo en constante crecimiento.
#
# ### 📜 **Certificaciones para Brillar**
# Obtén certificados digitales validados por Blockchain. Comparte tus logros en LinkedIn y ¡haz que todos te envidien en la próxima reunión familiar! 🎊
#
# ### 🎁 **¡Comienza ahora!**
# Inscríbete para obtener un **curso gratuito** de introducción al trading algorítmico con Python. ¡La única inversión que necesitas es tu tiempo!
#
# ---
#
# ¡Ven y únete a la aventura de aprendizaje en Frogames! Aquí tus sueños se convierten en habilidades y tal vez, solo tal vez, en una carrera de ensueño. 😎✨

# %% [markdown]
# ## Aplicaciones empresariales
#
# En este ejercicio, ampliamos el código del día 1 para realizar múltiples llamadas a LLM y generar un documento.
#
# En términos de técnicas, este es quizás el primer ejemplo de patrones de diseño de Agentic AI, ya que combinamos múltiples llamadas a LLM. Esto se abordará más en la semana 2 y luego volveremos a Agentic AI de manera importante en la semana 8, cuando construyamos una solución Agent completamente autónoma.
#
# En términos de aplicaciones empresariales, generar contenido de esta manera es uno de los casos de uso más comunes. Al igual que con el resumen, esto se puede aplicar a cualquier vertical empresarial. Escriba contenido de marketing, genere un tutorial de producto a partir de una especificación, cree contenido de correo electrónico personalizado y mucho más. Explore cómo puede aplicar la generación de contenido a su negocio e intente crear un prototipo de prueba de concepto.

# %%
web = Website("https://cursos.frogamesformacion.com")
print(web.title)
print(web.text[:500])
# Out:
# Frogames
# Ir al contenido principal
# Frogames
# Menú alternativo
# Menú
# Iniciar sesión
# Ganadora del premio 'Enseñanza online de datos y competencias digitales más innovadora de Europa, 2023'
# Pasión por
# aprender
# con los
# mejores
# En Frogames Formación te ayudamos a convertirte en todo un experto en: Programación de Videojuegos, Inteligencia Artificial, Machine Learning, Desarrollo de Apps, Data Science y mucho más.
# Aprende mientras te diviertes
# Cursos, Rutas y Suscripciones
# Certificados de finalización
# Qué encont
