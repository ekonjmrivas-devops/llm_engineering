# %% [markdown]
# # TAREA DE EJERCICIO
#
# Actualiza el proyecto del día 1 para resumir una página web y utilizar un modelo de código abierto que se ejecute localmente a través de Ollama en lugar de OpenAI
#
# Podrás utilizar esta técnica para todos los proyectos posteriores si prefiere no utilizar API de pago (closed source).
#
# **Beneficios:**
# 1. Sin cargos por API: código abierto
# 2. Los datos no salen de su ordenador
#
# **Desventajas:**
# 1. Tiene mucha menos potencia (parámetros) que el modelo Frontier
#
# ## Resumen de la instalación de Ollama
#
# ¡Simplemente visita [ollama.com](https://ollama.com) e instálalo!
#
# Una vez que hayas terminado, el servidor ollama ya debería estar ejecutándose localmente.
# Si entras en:
# [http://localhost:11434/](http://localhost:11434/)
#
# Debería ver el mensaje `Ollama se está ejecutando`.
#
# De lo contrario, abre una nueva Terminal (Mac) o Powershell (Windows) e introduce `ollama serve`.
# Luego, intenta entrar em [http://localhost:11434/](http://localhost:11434/) nuevamente.

# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constantes

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
# Crea una lista de mensajes utilizando el mismo formato que usamos para OpenAI

messages = [
    {"role": "user", "content": "Describe algunas de las aplicaciones comerciales de la IA generativa."}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# La Inteligencia Artificial (IA) generativa se refiere a un enfoque del aprendizaje automático que permite a los sistemas crear contenido nuevo y útil basándose en patrones y relaciones aprendidas de datos existentes. A continuación, se presentan algunas de las aplicaciones comerciales más destacadas de la IA generativa:
#
# 1. **Generación de contenido**: La IA puede generar texto, imágenes, videos y música que pueden ser utilizados en marketing, publicidad, contenido de medios sociales y más. Por ejemplo, las redes de noticias pueden utilizar herramientas de IA para generar artículos de noticias sobre eventos en tiempo real.
# 2. **Diseño de productos**: La IA generativa puede ayudar a diseñar productos más eficientes y atractivos mediante la creación de prototipos y modelos de diseño 3D. Esto puede ser especialmente útil en la industria del automóvil, la aeronáutica y la electrónica.
# 3. **Personalización**: La IA generativa puede ayudar a personalizar experiencias para los clientes, como recomendaciones de productos o servicios basadas en sus preferencias y comportamientos.
# 4. **Análisis de datos**: La IA generativa puede ayudar a analizar grandes cantidades de datos para identificar patrones y tendencias que pueden ser utilizados para tomar decisiones empresariales más informadas.
# 5. **Generación de personas virtuales**: La IA generativa puede generar personajes virtuales para juegos, películas y otros medios de entretenimiento.
# 6. **Automatización de procesos**: La IA generativa puede automatizar procesos repetitivos y aburridos, permitiendo a los empleados enfocarse en tareas más complejas y creativas.
# 7. **Creación de experiencias de realidad virtual (RV) y aumentada (RAV)**: La IA generativa puede ayudar a crear experiencias de RV y RAV más realistas y interactivas, lo que puede ser especialmente útil en la industria del entretenimiento.
#
# Algunos ejemplos de empresas que están utilizando la IA generativa incluyen:
#
# * Google: Utiliza la IA para generar contenido de noticias y publicidad.
# * Microsoft: Utiliza la IA para personalizar experiencias para los clientes y automatizar procesos.
# * Adobe: Utiliza la IA para generar imágenes y videos para campañas de marketing.
# * Spotify: Utiliza la IA para recomendar música a los usuarios.
#
# En resumen, la IA generativa tiene una amplia gama de aplicaciones comerciales que pueden ser utilizadas para mejorar la eficiencia, la innovación y la experiencia del cliente.

# %% [markdown]
# # Presentación del paquete ollama
#
# Ahora haremos lo mismo, pero utilizando el elegante paquete de Python ollama en lugar de una llamada HTTP directa.
#
# En esencia, se realiza la misma llamada que se indicó anteriormente al servidor ollama que se ejecuta en localhost:11434

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])

# %% [markdown]
# # AHORA el ejercicio para ti
#
# Toma el código del día 1 e incorpóralo aquí para crear un resumidor de sitios web que use Llama 3.2 ejecutándose localmente en lugar de OpenAI
